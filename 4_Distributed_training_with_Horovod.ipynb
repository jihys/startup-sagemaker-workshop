# %% [markdown]
# # [Module 4] Distributed training with horovod
# Horovod는 MPI(Message Passing Interface; 메세지 전달 인터페이스)를 기반으로 하는 분산 학습 프레임워크(distributed training framework)입니다. Horovod는 TensorFlow 버전 1.12 이상에서만 사용할 수 있습니다. 자세한 내용은 [Horovod README](https://github.com/uber/horovod)에서 확인할 수 있습니다.
#
# Horovod를 활성화하려면 학습 스크립트를 약간 수정해야 합니다. 본 실습에서 이를 직접 수행해 보겠습니다.

# %% [markdown]
# ## Create a training script that support Horovod distributed training
#
#
# ----
# ### TODO 1. Start horovod
# Horovod에 대응하기 위해 `main()` 함수에 아래 코드를 추가합니다.
#
# ```python
#     import horovod.keras as hvd
#     hvd.init()
#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth = True
#     config.gpu_options.visible_device_list = str(hvd.local_rank())
#     K.set_session(tf.Session(config=config))
# ```
#
# ----
# ### TODO 2. Configure callbacks
# `main()` 함수에서 callbacks을 추가합니다.
#
# ```python
#     callbacks.append(hvd.callbacks.BroadcastGlobalVariablesCallback(0))
#     callbacks.append(hvd.callbacks.MetricAverageCallback())
#     callbacks.append(hvd.callbacks.LearningRateWarmupCallback(warmup_epochs=5, verbose=1))
# ```
#
# `hvd.rank () == 0` 에서만 실행되도록 체크포인트 및 TensorBoard 콜백을 변경해 주세요.
# ```python
#     if hvd.rank() == 0:
#         callbacks.append(ModelCheckpoint(args.output_dir + '/checkpoint-{epoch}.h5'))
# ```
#
# ----
# ### TODO 3. Configure the optimizer
# Horovod에 대응하기 위해 아래의 절차들을 진행합니다.
#
#
# 1) `keras_model_fn` 함수에 hvd 인수를 추가합니다.
# ```python
# # Add hvd to the function. also add it in the function call
# def keras_model_fn(learning_rate, weight_decay, optimizer, momentum, hvd):
# ```
#
# 2) `size=1`을 `size=hvd.size()`로 변경해 주세요.
#
# 3) 코드를 아래와 같이 수정합니다.
#
# ```python
#  model.compile(loss='categorical_crossentropy',
#                   optimizer=opt,
#                   metrics=['accuracy'])
# ```
# 바로 앞에
# ```python
# opt = hvd.DistributedOptimizer(opt)
# ```
# 라인을 추가해 주세요.
#
# 4) `main()` 함수에서 model 인스턴스를 만들 때 hvd를 인수로 전달하도록 수정합니다.
#
# ```python
# model = keras_model_fn(args.learning_rate, args.weight_decay, args.optimizer, args.momentum, hvd)
# ```

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()

# %%
from sagemaker.tensorflow import TensorFlow

train_instance_type='ml.p3.8xlarge'
train_instance_count = 1
gpus_per_host = 4

num_of_shards = gpus_per_host * train_instance_count

# %%
sagemaker.__version__
# Out:
# '1.72.1'

# %% [markdown]
# ### Data split for Horovod and upload to S3

# %% [markdown]
# For Horovod, we need a dedicated input channel for each Horovod worker. In this example, we will use a instance with 4 GPUs (**ml.p3.8xlarge**). So we will shard the train data into four tfrecord files as below.

# %%
# %load_ext autoreload
#%reload_ext autoreload
# %autoreload 2

from shard import do_shard
from sagemaker.session import s3_input
#from sagemaker.inputs import TrainingInput
from sagemaker.tensorflow import TensorFlow
def shard_data_and_upload(local_data_dir, num_of_shards):
    do_shard(local_data_dir, num_of_shards)
    dataset_location = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-cifar10-tf')
    display(dataset_location)

    shuffle_config = sagemaker.session.ShuffleConfig(234)
    #shuffle_config = sagemaker.inputs.ShuffleConfig(234)
    
    print("shuffle_config:",shuffle_config)
    train_s3_uri_prefix = dataset_location

    remote_inputs = {}

    for idx in range(num_of_shards):
        train_s3_uri = f'{train_s3_uri_prefix}/train/{idx}/'
        train_s3_input = s3_input(train_s3_uri, shuffle_config=shuffle_config)
        #train_s3_input=TrainingInput(train_s3_uri, shuffle_config=shuffle_config)
        
        remote_inputs[f'train_{idx}'] = train_s3_input
        
        remote_inputs['validation_{}'.format(idx)] = '{}/validation'.format(dataset_location)

    remote_inputs['validation'] = '{}/validation'.format(dataset_location)
    remote_inputs['eval'] = '{}/eval'.format(dataset_location)
    
    return remote_inputs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
remote_inputs = shard_data_and_upload('./data', num_of_shards)
# Out:
# Generating ./data/train/0/train_0.tfrecords
# Generating ./data/train/1/train_1.tfrecords
# Generating ./data/train/2/train_2.tfrecords
# Generating ./data/train/3/train_3.tfrecords
# 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf'
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# shuffle_config: <sagemaker.session.ShuffleConfig object at 0x7ff8c00a0710>

# %%
remote_inputs
# Out:
# {'train_0': <sagemaker.inputs.s3_input at 0x7ff8c00a0a20>,
#  'validation_0': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_1': <sagemaker.inputs.s3_input at 0x7ff8c00a0a58>,
#  'validation_1': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_2': <sagemaker.inputs.s3_input at 0x7ff8b87c3c18>,
#  'validation_2': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_3': <sagemaker.inputs.s3_input at 0x7ff8b87c3ba8>,
#  'validation_3': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'validation': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'eval': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/eval'}

# %% [markdown]
# ## Run Distributed training with File mode
# 아래의 설정을 Estimator 객체에 전달하여 Horovod 분산 학습에 대한 설정을 할 수 있습니다.
# ```python
# distributions = {'mpi': {
#                     'enabled': True,
#                     'processes_per_host': # Number of Horovod processes per host
#                         }
#                 }
# ```

# %%
distributions = {'mpi': {
                    'enabled': True,
                    'processes_per_host': gpus_per_host
                        }
                }

metric_definitions = [
    {'Name': 'train:loss', 'Regex': '.*loss: ([0-9\\.]+) - accuracy: [0-9\\.]+.*'},
    {'Name': 'train:accuracy', 'Regex': '.*loss: [0-9\\.]+ - accuracy: ([0-9\\.]+).*'},
    {'Name': 'validation:accuracy', 'Regex': '.* - loss: [0-9\\.]+ - accuracy: [0-9\\.]+ - val_loss: [0-9\\.]+ - val_accuracy: ([0-9\\.]+).*'},
    {'Name': 'validation:loss', 'Regex': '.* - loss: [0-9\\.]+ - accuracy: [0-9\\.]+ - val_loss: ([0-9\\.]+) - val_accuracy: [0-9\\.]+.*'},
    {'Name': 'sec/steps', 'Regex': '.* ([0-9]+)ms/step - loss: [0-9\\.]+ - accuracy: [0-9\\.]+ - val_loss: [0-9\\.]+ - val_accuracy: [0-9\\.]+'}
]
hyperparameters = {'epochs': 10, 'batch-size' : 256}

input_mode = 'File'

# %%
source_dir = os.path.join(os.getcwd(), 'training_script')
estimator_dist = TensorFlow(base_job_name='horovod-cifar10-tf',
                       entry_point='cifar10_keras_dist_tf2.py',
                       source_dir=source_dir,
                       role=role,
                       framework_version='2.1.0',
                       py_version='py3',
                       hyperparameters=hyperparameters,
                       train_instance_count=train_instance_count,
                       #instance_count=train_instance_count,
                       train_instance_type=train_instance_type,
                       #instance_type=train_instance_type,
                       tags = [{'Key' : 'Project', 'Value' : 'cifar10'},{'Key' : 'TensorBoard', 'Value' : 'horovod-file'}],
                       metric_definitions=metric_definitions,
                       distributions=distributions,
                       input_mode=input_mode)
# Out:
# Parameter distribution will be renamed to {'mpi': {'enabled': True, 'processes_per_host': 4}} in SageMaker Python SDK v2.

# %%
#estimator_dist.fit(remote_inputs, wait=False)
estimator_dist.fit(remote_inputs, wait=True)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-12-07 15:21:34 Starting - Starting the training job...
# 2020-12-07 15:21:38 Starting - Launching requested ML instances.........
# 2020-12-07 15:23:30 Starting - Preparing the instances for training......
# 2020-12-07 15:24:25 Downloading - Downloading input data
# 2020-12-07 15:24:25 Training - Downloading the training image........2020-12-07 15:25:41,082 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-12-07 15:25:41,498 sagemaker-containers INFO     Starting MPI run as worker node.
# 2020-12-07 15:25:41,498 sagemaker-containers INFO     Creating SSH daemon.
# 2020-12-07 15:25:41,504 sagemaker-containers INFO     Waiting for MPI workers to establish their SSH connections
# 2020-12-07 15:25:41,504 sagemaker-containers INFO     Env Hosts: ['algo-1'] Hosts: ['algo-1:4'] process_per_hosts: 4 num_processes: 4
# 2020-12-07 15:25:41,506 sagemaker-containers INFO     Network interface name: eth0
# 2020-12-07 15:25:41,552 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_num_of_processes_per_host": 4,
#         "sagemaker_mpi_custom_mpi_options": "",
#         "sagemaker_mpi_enabled": true
#     },
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "train_2": "/opt/ml/input/data/train_2",
#         "train_1": "/opt/ml/input/data/train_1",
#         "validation_3": "/opt/ml/input/data/validation_3",
#         "train_0": "/opt/ml/input/data/train_0",
#         "validation_2": "/opt/ml/input/data/validation_2",
#         "validation_1": "/opt/ml/input/data/validation_1",
#         "validation_0": "/opt/ml/input/data/validation_0",
#         "validation": "/opt/ml/input/data/validation",
#         "train_3": "/opt/ml/input/data/train_3"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 256,
#         "model_dir": "/opt/ml/model",
#         "epochs": 10
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_2": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_1": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_3": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_0": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_2": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_1": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_0": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_3": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "horovod-cifar10-tf-2020-12-07-15-21-33-502",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-12-07-15-21-33-502/source/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_dist_tf2",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_dist_tf2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":256,"epochs":10,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=cifar10_keras_dist_tf2.py
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":4}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train_0","train_1","train_2","train_3","validation","validation_0","validation_1","validation_2","validation_3"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_dist_tf2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-12-07-15-21-33-502/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":4},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train_0":"/opt/ml/input/data/train_0","train_1":"/opt/ml/input/data/train_1","train_2":"/opt/ml/input/data/train_2","train_3":"/opt/ml/input/data/train_3","validation":"/opt/ml/input/data/validation","validation_0":"/opt/ml/input/data/validation_0","validation_1":"/opt/ml/input/data/validation_1","validation_2":"/opt/ml/input/data/validation_2","validation_3":"/opt/ml/input/data/validation_3"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":256,"epochs":10,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"horovod-cifar10-tf-2020-12-07-15-21-33-502","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-12-07-15-21-33-502/source/sourcedir.tar.gz","module_name":"cifar10_keras_dist_tf2","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_dist_tf2.py"}
# SM_USER_ARGS=["--batch-size","256","--epochs","10","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAIN_2=/opt/ml/input/data/train_2
# SM_CHANNEL_TRAIN_1=/opt/ml/input/data/train_1
# SM_CHANNEL_VALIDATION_3=/opt/ml/input/data/validation_3
# SM_CHANNEL_TRAIN_0=/opt/ml/input/data/train_0
# SM_CHANNEL_VALIDATION_2=/opt/ml/input/data/validation_2
# SM_CHANNEL_VALIDATION_1=/opt/ml/input/data/validation_1
# SM_CHANNEL_VALIDATION_0=/opt/ml/input/data/validation_0
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN_3=/opt/ml/input/data/train_3
# SM_HP_BATCH-SIZE=256
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=10
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1:4 -np 4 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to socket -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.6/dist-packages/gethostname.cpython-36m-x86_64-linux-gnu.so -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_EVAL -x SM_CHANNEL_TRAIN_2 -x SM_CHANNEL_TRAIN_1 -x SM_CHANNEL_VALIDATION_3 -x SM_CHANNEL_TRAIN_0 -x SM_CHANNEL_VALIDATION_2 -x SM_CHANNEL_VALIDATION_1 -x SM_CHANNEL_VALIDATION_0 -x SM_CHANNEL_VALIDATION -x SM_CHANNEL_TRAIN_3 -x SM_HP_BATCH-SIZE -x SM_HP_MODEL_DIR -x SM_HP_EPOCHS -x PYTHONPATH /usr/bin/python3 -m mpi4py cifar10_keras_dist_tf2.py --batch-size 256 --epochs 10 --model_dir /opt/ml/model
#
#
#  Data for JOB [58896,1] offset 0 Total slots allocated 4
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-0-86-31#011Num slots: 4#011Max slots: 0#011Num procs: 4
#  #011Process OMPI jobid: [58896,1] App: 0 Process rank: 0 Bound: UNBOUND
#  #011Process OMPI jobid: [58896,1] App: 0 Process rank: 1 Bound: UNBOUND
#  #011Process OMPI jobid: [58896,1] App: 0 Process rank: 2 Bound: UNBOUND
#  #011Process OMPI jobid: [58896,1] App: 0 Process rank: 3 Bound: UNBOUND
#
#  =============================================================
# --------------------------------------------------------------------------
# WARNING: Open MPI tried to bind a process but failed.  This is a
# warning only; your job will continue, though performance may
# be degraded.
#
#   Local host:        ip-10-0-86-31
#   Application name:  /usr/bin/python3
#   Error message:     failed to bind memory
#   Location:          rtc_hwloc.c:447
#
# --------------------------------------------------------------------------
# [1,1]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-12-07-15-21-33-502/model
# [1,1]<stderr>:Using TensorFlow backend.
# [1,2]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-12-07-15-21-33-502/model
# [1,2]<stderr>:Using TensorFlow backend.
# [1,3]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-12-07-15-21-33-502/model
# [1,3]<stderr>:Using TensorFlow backend.
# [1,0]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-12-07-15-21-33-502/model
# [1,0]<stderr>:Using TensorFlow backend.
# [1,0]<stdout>:hvd: <module 'horovod.keras' from '/usr/local/lib/python3.6/dist-packages/horovod/keras/__init__.py'>
# [1,0]<stdout>:---------ERROR-----
# [1,0]<stdout>:Channel Name: train_0
# [1,1]<stdout>:hvd: <module 'horovod.keras' from '/usr/local/lib/python3.6/dist-packages/horovod/keras/__init__.py'>
# [1,1]<stdout>:---------ERROR-----
# [1,1]<stdout>:Channel Name: train_1
# [1,2]<stdout>:hvd: <module 'horovod.keras' from '/usr/local/lib/python3.6/dist-packages/horovod/keras/__init__.py'>
# [1,2]<stdout>:---------ERROR-----
# [1,2]<stdout>:Channel Name: train_2
# [1,3]<stdout>:hvd: <module 'horovod.keras' from '/usr/local/lib/python3.6/dist-packages/horovod/keras/__init__.py'>
# [1,3]<stdout>:---------ERROR-----
# [1,3]<stdout>:Channel Name: train_3
# [1,2]<stdout>:hvd: None
# [1,2]<stdout>:---------ERROR-----
# [1,2]<stdout>:Channel Name: eval
# [1,3]<stdout>:hvd: None
# [1,3]<stdout>:---------ERROR-----
# [1,3]<stdout>:Channel Name: eval
# [1,1]<stdout>:hvd: None
# [1,1]<stdout>:---------ERROR-----
# [1,1]<stdout>:Channel Name: eval
# [1,0]<stdout>:hvd: None
# [1,0]<stdout>:---------ERROR-----
# [1,0]<stdout>:Channel Name: eval
# [1,3]<stdout>:hvd: <module 'horovod.keras' from '/usr/local/lib/python3.6/dist-packages/horovod/keras/__init__.py'>
# [1,3]<stdout>:---------ERROR-----
# [1,3]<stdout>:Channel Name: validation_3
# [1,2]<stdout>:hvd: <module 'horovod.keras' from '/usr/local/lib/python3.6/dist-packages/horovod/keras/__init__.py'>
# [1,2]<stdout>:---------ERROR-----
# [1,2]<stdout>:Channel Name: validation_2
# [1,1]<stdout>:hvd: <module 'horovod.keras' from '/usr/local/lib/python3.6/dist-packages/horovod/keras/__init__.py'>
# [1,1]<stdout>:---------ERROR-----
# [1,1]<stdout>:Channel Name: validation_1
# [1,0]<stdout>:hvd: <module 'horovod.keras' from '/usr/local/lib/python3.6/dist-packages/horovod/keras/__init__.py'>
# [1,0]<stdout>:---------ERROR-----
# [1,0]<stdout>:Channel Name: validation_0
# [ip-10-0-86-31.us-east-2.compute.internal:00053] 3 more processes have sent help message help-orte-odls-default.txt / memory not bound
# [ip-10-0-86-31.us-east-2.compute.internal:00053] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [1,1]<stderr>:INFO:root:Starting training
# [1,2]<stderr>:INFO:root:Starting training
# [1,3]<stderr>:INFO:root:Starting training
# [1,0]<stderr>:INFO:root:Starting training
# [1,2]<stdout>:[2020-12-07 15:25:47.603 algo-1:60 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,1]<stdout>:[2020-12-07 15:25:47.603 algo-1:59 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,3]<stdout>:[2020-12-07 15:25:47.603 algo-1:61 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,2]<stdout>:[2020-12-07 15:25:47.603 algo-1:60 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,1]<stdout>:[2020-12-07 15:25:47.603 algo-1:59 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,3]<stdout>:[2020-12-07 15:25:47.603 algo-1:61 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,2]<stdout>:[2020-12-07 15:25:47.603 algo-1:60 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,3]<stdout>:[2020-12-07 15:25:47.603 algo-1:61 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,1]<stdout>:[2020-12-07 15:25:47.603 algo-1:59 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,0]<stdout>:[2020-12-07 15:25:47.605 algo-1:58 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,0]<stdout>:[2020-12-07 15:25:47.605 algo-1:58 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,0]<stdout>:[2020-12-07 15:25:47.606 algo-1:58 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,3]<stdout>:[2020-12-07 15:25:47.647 algo-1:61 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,1]<stdout>:[2020-12-07 15:25:47.647 algo-1:59 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,2]<stdout>:[2020-12-07 15:25:47.648 algo-1:60 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,3]<stdout>:Epoch 1/10
# [1,1]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,0]<stdout>:[2020-12-07 15:25:48.076 algo-1:58 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,0]<stdout>:Epoch 1/10
# 2020-12-07 15:25:36 Training - Training image download completed. Training in progress.[1,2]<stdout>:[2020-12-07 15:25:51.275 algo-1:60 INFO hook.py:364] Monitoring the collections: losses, sm_metrics, metrics
# [1,1]<stdout>:[2020-12-07 15:25:51.320 algo-1:59 INFO hook.py:364] Monitoring the collections: metrics, losses, sm_metrics
# [1,3]<stdout>:[2020-12-07 15:25:51.381 algo-1:61 INFO hook.py:364] Monitoring the collections: losses, sm_metrics, metrics
# [1,0]<stdout>:[2020-12-07 15:25:51.819 algo-1:58 INFO hook.py:364] Monitoring the collections: metrics, losses, sm_metrics
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.86.31<0>
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,0]<stdout>:
# [1,0]<stdout>:algo-1:58:218 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:NCCL version 2.4.7+cuda10.1
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO NET/Socket : Using [0]eth0:10.0.86.31<0>
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,3]<stdout>:
# [1,3]<stdout>:algo-1:61:213 [3] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO NET/Socket : Using [0]eth0:10.0.86.31<0>
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO NET/Socket : Using [0]eth0:10.0.86.31<0>
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,2]<stdout>:
# [1,2]<stdout>:algo-1:60:211 [2] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,1]<stdout>:
# [1,1]<stdout>:algo-1:59:210 [1] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Setting affinity for GPU 3 to ffffffff
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Setting affinity for GPU 1 to ffffffff
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Setting affinity for GPU 2 to ffffffff
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Setting affinity for GPU 0 to ffffffff
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Channel 00 :    0   1   2   3
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Channel 01 :    0   2   1   3
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Channel 02 :    0   3   1   2
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Channel 03 :    0   3   2   1
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Channel 04 :    0   1   2   3
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Channel 05 :    0   2   1   3
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Channel 06 :    0   3   1   2
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Channel 07 :    0   3   2   1
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 00 : 1[1] -> 2[2] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Ring 00 : 0[0] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Ring 00 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 00 : 2[2] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 01 : 1[1] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Ring 01 : 0[0] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Ring 01 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 01 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Ring 02 : 0[0] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 02 : 1[1] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Ring 02 : 3[3] -> 1[1] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 02 : 2[2] -> 0[0] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 03 : 1[1] -> 0[0] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Ring 03 : 0[0] -> 3[3] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 03 : 2[2] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Ring 03 : 3[3] -> 2[2] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Ring 04 : 0[0] -> 1[1] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 04 : 1[1] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Ring 04 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 04 : 2[2] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 05 : 1[1] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Ring 05 : 0[0] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Ring 05 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 05 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Ring 06 : 0[0] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 06 : 1[1] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Ring 06 : 3[3] -> 1[1] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 06 : 2[2] -> 0[0] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 07 : 1[1] -> 0[0] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Ring 07 : 0[0] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Using 256 threads, Min Comp Cap 7, Trees disabled
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO Ring 07 : 3[3] -> 2[2] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 07 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO comm 0x7fe94c324ba0 rank 0 nranks 4 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO comm 0x7f3520311f90 rank 1 nranks 4 cudaDev 1 nvmlDev 1 - Init COMPLETE
# [1,3]<stdout>:algo-1:61:213 [3] NCCL INFO comm 0x7f8994311990 rank 3 nranks 4 cudaDev 3 nvmlDev 3 - Init COMPLETE
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO comm 0x7fa458311e20 rank 2 nranks 4 cudaDev 2 nvmlDev 2 - Init COMPLETE
# [1,0]<stdout>:algo-1:58:218 [0] NCCL INFO Launch mode Parallel
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 294912, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 294912, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 294912, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 10240, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 10240, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 10240, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 147456, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 147456, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 147456, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 36864, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 36864, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 36864, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 524288, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 524288, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 524288, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 73728, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 73728, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 18432, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 18432, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 18432, errno = 1
# [1,0]<stderr>:[algo-1:00058] Read -1, expected 5809, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# ...
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 524288, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 524288, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 524288, errno = 1
# [1,0]<stderr>:ERROR:root:'NoneType' object has no attribute 'write'
# [1,0]<stderr>:WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.886734). Check your callbacks.
# [1,0]<stderr>:WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.886734). Check your callbacks.
# [1,0]<stderr>:WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.518912). Check your callbacks.
# [1,0]<stderr>:WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.518912). Check your callbacks.
# [1,0]<stderr>:WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.260591). Check your callbacks.
# [1,0]<stderr>:WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.260591). Check your callbacks.
# [1,3]<stdout>:Epoch 1/10
# [1,1]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00001: saving model to /opt/ml/output/checkpoint-1.ckpt
# [1,3]<stderr>:ERROR:root:'NoneType' object has no attribute 'write'
# [1,1]<stderr>:ERROR:root:'NoneType' object has no attribute 'write'
# [1,2]<stderr>:ERROR:root:'NoneType' object has no attribute 'write'
# [1,3]<stdout>:39/39 - 13s - loss: 2.1983 - accuracy: 0.2336 - val_loss: 2.2584 - val_accuracy: 0.1783
# [1,1]<stdout>:39/39 - 13s - loss: 2.2059 - accuracy: 0.2336 - val_loss: 2.2584 - val_accuracy: 0.1783
# [1,2]<stdout>:39/39 - 13s - loss: 2.1665 - accuracy: 0.2336 - val_loss: 2.2584 - val_accuracy: 0.1783
# [1,3]<stdout>:Epoch 2/10
# [1,1]<stdout>:Epoch 2/10
# [1,2]<stdout>:Epoch 2/10
# [1,0]<stdout>:39/39 - 13s - loss: 2.1935 - accuracy: 0.2336 - val_loss: 2.2584 - val_accuracy: 0.1783
# [1,0]<stdout>:Epoch 2/10
# [1,1]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,3]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00002: saving model to /opt/ml/output/checkpoint-2.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 1.6824 - accuracy: 0.3677 - val_loss: 2.0392 - val_accuracy: 0.2536
# [1,3]<stdout>:39/39 - 2s - loss: 1.7080 - accuracy: 0.3677 - val_loss: 2.0392 - val_accuracy: 0.2536
# [1,2]<stdout>:39/39 - 2s - loss: 1.6566 - accuracy: 0.3677 - val_loss: 2.0392 - val_accuracy: 0.2536
# [1,1]<stdout>:Epoch 3/10
# [1,3]<stdout>:Epoch 3/10
# [1,2]<stdout>:Epoch 3/10
# [1,0]<stdout>:39/39 - 2s - loss: 1.6965 - accuracy: 0.3677 - val_loss: 2.0392 - val_accuracy: 0.2536
# [1,0]<stdout>:Epoch 3/10
# [1,1]<stdout>:Epoch 1/10
# [1,3]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00003: saving model to /opt/ml/output/checkpoint-3.ckpt
# [1,2]<stdout>:39/39 - 2s - loss: 1.5103 - accuracy: 0.4403 - val_loss: 1.6389 - val_accuracy: 0.3809
# [1,3]<stdout>:39/39 - 2s - loss: 1.5267 - accuracy: 0.4403 - val_loss: 1.6389 - val_accuracy: 0.3809
# [1,1]<stdout>:39/39 - 2s - loss: 1.5261 - accuracy: 0.4403 - val_loss: 1.6389 - val_accuracy: 0.3809
# [1,2]<stdout>:Epoch 4/10
# [1,1]<stdout>:Epoch 4/10
# [1,3]<stdout>:Epoch 4/10
# [1,0]<stdout>:39/39 - 2s - loss: 1.4980 - accuracy: 0.4403 - val_loss: 1.6389 - val_accuracy: 0.3809
# [1,0]<stdout>:Epoch 4/10
# [1,3]<stdout>:Epoch 1/10
# [1,1]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00004: saving model to /opt/ml/output/checkpoint-4.ckpt
# [1,2]<stdout>:39/39 - 2s - loss: 1.3409 - accuracy: 0.5070 - val_loss: 1.8304 - val_accuracy: 0.3555
# [1,3]<stdout>:39/39 - 2s - loss: 1.3736 - accuracy: 0.5070 - val_loss: 1.8304 - val_accuracy: 0.3555
# [1,1]<stdout>:39/39 - 2s - loss: 1.3536 - accuracy: 0.5070 - val_loss: 1.8304 - val_accuracy: 0.3555
# [1,2]<stdout>:Epoch 5/10
# [1,3]<stdout>:Epoch 5/10
# [1,1]<stdout>:Epoch 5/10
# [1,0]<stdout>:39/39 - 2s - loss: 1.3481 - accuracy: 0.5070 - val_loss: 1.8304 - val_accuracy: 0.3555
# [1,0]<stdout>:Epoch 5/10
# [1,1]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,3]<stdout>:Epoch 1/10
# [1,2]<stdout>:
# [1,2]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.004.
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.004.
# [1,3]<stdout>:
# [1,3]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.004.
# [1,1]<stdout>:
# [1,1]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.004.
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00005: saving model to /opt/ml/output/checkpoint-5.ckpt
# [1,2]<stdout>:39/39 - 2s - loss: 1.2195 - accuracy: 0.5588 - val_loss: 2.1894 - val_accuracy: 0.3172
# [1,3]<stdout>:39/39 - 2s - loss: 1.2470 - accuracy: 0.5588 - val_loss: 2.1894 - val_accuracy: 0.3172
# [1,1]<stdout>:39/39 - 2s - loss: 1.2307 - accuracy: 0.5588 - val_loss: 2.1894 - val_accuracy: 0.3172
# [1,3]<stdout>:Epoch 6/10
# [1,2]<stdout>:Epoch 6/10
# [1,1]<stdout>:Epoch 6/10
# [1,0]<stdout>:39/39 - 2s - loss: 1.2268 - accuracy: 0.5588 - val_loss: 2.1894 - val_accuracy: 0.3172
# [1,0]<stdout>:Epoch 6/10
# [1,3]<stdout>:Epoch 1/10
# [1,1]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00006: saving model to /opt/ml/output/checkpoint-6.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 1.1703 - accuracy: 0.5899 - val_loss: 2.2562 - val_accuracy: 0.3349
# [1,1]<stdout>:39/39 - 2s - loss: 1.1386 - accuracy: 0.5899 - val_loss: 2.2562 - val_accuracy: 0.3349
# [1,2]<stdout>:39/39 - 2s - loss: 1.1170 - accuracy: 0.5899 - val_loss: 2.2562 - val_accuracy: 0.3349
# [1,3]<stdout>:Epoch 7/10
# [1,1]<stdout>:Epoch 7/10
# [1,2]<stdout>:Epoch 7/10
# [1,0]<stdout>:39/39 - 2s - loss: 1.1359 - accuracy: 0.5899 - val_loss: 2.2562 - val_accuracy: 0.3349
# [1,0]<stdout>:Epoch 7/10
# [1,1]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,3]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00007: saving model to /opt/ml/output/checkpoint-7.ckpt
# [1,2]<stdout>:39/39 - 2s - loss: 1.0553 - accuracy: 0.6193 - val_loss: 1.2040 - val_accuracy: 0.5616
# [1,3]<stdout>:39/39 - 2s - loss: 1.0899 - accuracy: 0.6193 - val_loss: 1.2040 - val_accuracy: 0.5616
# [1,1]<stdout>:39/39 - 2s - loss: 1.0785 - accuracy: 0.6193 - val_loss: 1.2040 - val_accuracy: 0.5616
# [1,2]<stdout>:Epoch 8/10
# [1,1]<stdout>:Epoch 8/10
# [1,3]<stdout>:Epoch 8/10
# [1,0]<stdout>:39/39 - 2s - loss: 1.0545 - accuracy: 0.6193 - val_loss: 1.2040 - val_accuracy: 0.5616
# [1,0]<stdout>:Epoch 8/10
# [1,2]<stdout>:Epoch 1/10
# [1,1]<stdout>:Epoch 1/10
# [1,3]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00008: saving model to /opt/ml/output/checkpoint-8.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 0.9972 - accuracy: 0.6506 - val_loss: 1.7058 - val_accuracy: 0.4341
# [1,1]<stdout>:39/39 - 2s - loss: 0.9978 - accuracy: 0.6506 - val_loss: 1.7058 - val_accuracy: 0.4341
# [1,2]<stdout>:39/39 - 2s - loss: 0.9849 - accuracy: 0.6506 - val_loss: 1.7058 - val_accuracy: 0.4341
# [1,3]<stdout>:Epoch 9/10
# [1,1]<stdout>:Epoch 9/10
# [1,2]<stdout>:Epoch 9/10
# [1,0]<stdout>:39/39 - 2s - loss: 0.9840 - accuracy: 0.6506 - val_loss: 1.7058 - val_accuracy: 0.4341
# [1,0]<stdout>:Epoch 9/10
# [1,1]<stdout>:Epoch 1/10
# [1,3]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,2]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00009: saving model to /opt/ml/output/checkpoint-9.ckpt
# [1,2]<stdout>:39/39 - 1s - loss: 0.9194 - accuracy: 0.6625 - val_loss: 1.3624 - val_accuracy: 0.5582
# [1,3]<stdout>:39/39 - 1s - loss: 0.9878 - accuracy: 0.6625 - val_loss: 1.3624 - val_accuracy: 0.5582
# [1,1]<stdout>:39/39 - 1s - loss: 0.9634 - accuracy: 0.6625 - val_loss: 1.3624 - val_accuracy: 0.5582
# [1,2]<stdout>:Epoch 10/10
# [1,3]<stdout>:Epoch 10/10
# [1,1]<stdout>:Epoch 10/10
# [1,0]<stdout>:39/39 - 1s - loss: 0.9589 - accuracy: 0.6625 - val_loss: 1.3624 - val_accuracy: 0.5582
# [1,0]<stdout>:Epoch 10/10
# [1,2]<stdout>:Epoch 1/10
# [1,3]<stdout>:Epoch 1/10
# [1,1]<stdout>:Epoch 1/10
# [1,0]<stdout>:Epoch 1/10
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00010: saving model to /opt/ml/output/checkpoint-10.ckpt
# [1,1]<stdout>:39/39 - 1s - loss: 0.9127 - accuracy: 0.6830 - val_loss: 1.0316 - val_accuracy: 0.6506
# [1,2]<stdout>:39/39 - 1s - loss: 0.8743 - accuracy: 0.6830 - val_loss: 1.0316 - val_accuracy: 0.6506
# [1,3]<stdout>:39/39 - 1s - loss: 0.9154 - accuracy: 0.6830 - val_loss: 1.0316 - val_accuracy: 0.6506
# [1,1]<stdout>:[2020-12-07 15:26:17.999 algo-1:59 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,2]<stdout>:[2020-12-07 15:26:17.999 algo-1:60 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,3]<stdout>:[2020-12-07 15:26:17.999 algo-1:61 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,0]<stdout>:39/39 - 1s - loss: 0.9011 - accuracy: 0.6830 - val_loss: 1.0316 - val_accuracy: 0.6506
# [1,0]<stdout>:39/39 - 1s - loss: 1.0651 - accuracy: 0.6343
# [1,0]<stderr>:INFO:root:Test loss:1.0651108912932568
# [1,0]<stderr>:INFO:root:Test accuracy:0.6343148946762085
# [1,0]<stderr>:2020-12-07 15:26:20.737111: W tensorflow/python/util/util.cc:319] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2020-12-07 15:26:35 Uploading - Uploading generated training model
# 2020-12-07 15:26:35 Completed - Training job completed
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:If using Keras pass *_constraint arguments to layers.
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:If using Keras pass *_constraint arguments to layers.
# [1,0]<stderr>:INFO:tensorflow:Assets written to: /opt/ml/model/assets
# [1,0]<stderr>:INFO:tensorflow:Assets written to: /opt/ml/model/assets
# [1,0]<stdout>:[2020-12-07 15:26:22.678 algo-1:58 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# 2020-12-07 15:26:23,678 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving containers. The SavedModel bundle is under directory "model", not a numeric name.
# 2020-12-07 15:26:23,678 sagemaker-containers INFO     Reporting training SUCCESS
# Training seconds: 142
# Billable seconds: 142

# %% [markdown]
# In this example, we set wait=False if you want to see the output logs, change this to wait=True

# %% [markdown]
# ## Distributed training with Horovod and Pipe Mode input
# Ditributed training with Horovod can also utilize SageMaker Pipe Mode.

# %% [markdown]
# Amazon SageMaker를 사용하면 Pipe 입력 모드를 사용하여 교육 작업을 생성할 수 있습니다. **Pipe 입력 모드를 사용하면 S3의 학습 데이터셋을 노트북 인스턴스의 로컬 디스크로 다운로드하는 대신 학습 인스턴스로 직접 스트리밍합니다.** 즉, 학습 작업이 더 빨리 시작되고 더 빨리 완료되며 더 적은 디스크 공간이 필요합니다.
#
# SageMaker TensorFlow는 SageMaker에서 Pipe 입력 모드를 쉽게 활용할 수있는 `tf.data.Dataset`의 구현을 제공합니다. `tf.data.Dataset`을`sagemaker_tensorflow.PipeModeDataset`으로 바꾸면 학습 인스턴스로 스트리밍되는 TFRecord를 읽을 수 있습니다.
#
# 여러분의 entry_point 스크립트에서 `PipeModeDataset`을 `Dataset`처럼 사용할 수 있습니다. 아래 예시는 '학습' 채널에서 TFRecords를 읽을 수있는`PipeModeDataset`을 생성하는 예시입니다.
#
# ```python
# from sagemaker_tensorflow import PipeModeDataset
#
# features = {
#     'data': tf.FixedLenFeature([], tf.string),
#     'labels': tf.FixedLenFeature([], tf.int64),
# }
#
# def parse(record):
#     parsed = tf.parse_single_example(record, features)
#     return ({
#         'data': tf.decode_raw(parsed['data'], tf.float64)
#     }, parsed['labels'])
#
# def train_input_fn(training_dir, hyperparameters):
#     ds = PipeModeDataset(channel='training', record_format='TFRecord')
#     ds = ds.repeat(20)
#     ds = ds.prefetch(10)
#     ds = ds.map(parse, num_parallel_calls=10)
#     ds = ds.batch(64)
#     return ds
# ```
#
# Pipe 입력 모드에서 학습 작업을 구동하려면, 아래 예시처럼 여러분의 TensorFlow Estimator에서 `input_mode='Pipe'` 인자를 추가해 주세요.
#
# ```python
# from sagemaker.tensorflow import TensorFlow
#
# tf_estimator = TensorFlow(entry_point='tf-train-with-pipemodedataset.py', role='SageMakerRole',
#                           train_instance_count=1, train_instance_type='ml.c5.2xlarge',
#                           framework_version='1.14.0', input_mode='Pipe')
#
# tf_estimator.fit('s3://bucket/path/to/training/data')
# ```

# %% [markdown]
# ## Create a training script that support pipemode datasets
#
# ----
# ### TODO 1.
# `cifar10_keras_pipe_tf2.py`에서 아래와 같이 `PipeModeDataset`를 import해 주세요.
# ```python
# from sagemaker_tensorflow import PipeModeDataset
# ```
# ----
# ### TODO 2.
# ```python
# def _input(epochs, batch_size, channel, channel_name):
# ```
# 함수 내에서
# ```python
# dataset = tf.data.TFRecordDataset(filenames)
# ```
# 을
# ```python
# dataset = PipeModeDataset(channel=channel_name, record_format='TFRecord')
# ```
# 로 수정해 주세요.
#
# 자세한 내용은 SageMaker-python-sdk [documentation](https://sagemaker.readthedocs.io/en/stable/using_tf.html#training-with-pipe-mode-using-pipemodedataset)를 참조해 주세요.

# %%
from sagemaker.tensorflow import TensorFlow

train_instance_type='ml.p3.8xlarge'
train_instance_count = 1
gpus_per_host = 4

num_of_shards = gpus_per_host * train_instance_count

# %%
distributions = {'mpi': {
                    'enabled': True,
                    'processes_per_host': gpus_per_host
                        }
                }

metric_definitions = [
    {'Name': 'train:loss', 'Regex': '.*loss: ([0-9\\.]+) - acc: [0-9\\.]+.*'},
    {'Name': 'train:accuracy', 'Regex': '.*loss: [0-9\\.]+ - acc: ([0-9\\.]+).*'},
    {'Name': 'validation:accuracy', 'Regex': '.*step - loss: [0-9\\.]+ - acc: [0-9\\.]+ - val_loss: [0-9\\.]+ - val_acc: ([0-9\\.]+).*'},
    {'Name': 'validation:loss', 'Regex': '.*step - loss: [0-9\\.]+ - acc: [0-9\\.]+ - val_loss: ([0-9\\.]+) - val_acc: [0-9\\.]+.*'},
    {'Name': 'sec/steps', 'Regex': '.* - \d+s (\d+)[mu]s/step - loss: [0-9\\.]+ - acc: [0-9\\.]+ - val_loss: [0-9\\.]+ - val_acc: [0-9\\.]+'}
]

hyperparameters = {'epochs': 10, 'batch-size' : 256}

input_mode = 'Pipe'

# %%
remote_inputs = shard_data_and_upload('./data', num_of_shards)
# Out:
# Generating ./data/train/0/train_0.tfrecords
# Generating ./data/train/1/train_1.tfrecords
# Generating ./data/train/2/train_2.tfrecords
# Generating ./data/train/3/train_3.tfrecords
# 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf'
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# shuffle_config: <sagemaker.session.ShuffleConfig object at 0x7ff861331fd0>

# %%
remote_inputs
# Out:
# {'train_0': <sagemaker.inputs.s3_input at 0x7ff861331f98>,
#  'validation_0': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_1': <sagemaker.inputs.s3_input at 0x7ff861522940>,
#  'validation_1': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_2': <sagemaker.inputs.s3_input at 0x7ff86132a048>,
#  'validation_2': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_3': <sagemaker.inputs.s3_input at 0x7ff86132a668>,
#  'validation_3': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'validation': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'eval': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/eval'}

# %%
source_dir = os.path.join(os.getcwd(), 'training_script')
estimator_dist = TensorFlow(base_job_name='horovod-cifar10-tf',
                       entry_point='cifar10_keras_dist_tf2.py',
                       source_dir=source_dir,
                       role=role,
                       framework_version='2.1.0',
                       py_version='py3',
                       hyperparameters=hyperparameters,
                       train_instance_count=train_instance_count,
                       train_instance_type=train_instance_type,
                       tags = [{'Key' : 'Project', 'Value' : 'cifar10'},{'Key' : 'TensorBoard', 'Value' : 'horovod'}],
                       metric_definitions=metric_definitions,
                       distributions=distributions,
                       input_mode=input_mode)
# Out:
# Parameter distribution will be renamed to {'mpi': {'enabled': True, 'processes_per_host': 4}} in SageMaker Python SDK v2.

# %%
estimator_dist.fit(remote_inputs, wait=False)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %% [markdown]
# 학습 완료 후 Billable seconds도 확인해 보세요. Billable seconds는 실제로 학습 수행 시 과금되는 시간입니다.
# ```
# Billable seconds: <time>
# ```
#
# 참고로, `ml.p2.xlarge` 인스턴스로 10 epoch 학습 시 전체 6분~7분이 소요되고, 실제 학습에 소요되는 시간은 3분~4분이 소요됩니다.

# %% [markdown]
# **수고 하셨습니다.**
#
# 여러 분은 이제 분산 학습에 SageMaker 학습 작업을 사용할 수 있습니다.
# 다음 노트북으로 계속 진행하기 전에 CloudWatch 및 TensorBoard의 distribution job metrics를 살펴 보세요.
# TensorBoard를 사용하여 여러분이 실행한 다른 작업을 비교할 수 있습니다.
#
# TensorBoard 실행 시 아래의 인자값을 참조해 주세요.<br>
# `--logdir dist:dist_model_dir,pipe:pipe_model_dir,file:normal_job_model_dir`
