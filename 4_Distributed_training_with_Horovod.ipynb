# %% [markdown]
# # [Module 4] Distributed training with horovod
# Horovod는 MPI(Message Passing Interface; 메세지 전달 인터페이스)를 기반으로 하는 분산 학습 프레임워크(distributed training framework)입니다. Horovod는 TensorFlow 버전 1.12 이상에서만 사용할 수 있습니다. 자세한 내용은 [Horovod README](https://github.com/uber/horovod)에서 확인할 수 있습니다.
#
# Horovod를 활성화하려면 학습 스크립트를 약간 수정해야 합니다. 본 실습에서 이를 직접 수행해 보겠습니다.

# %% [markdown]
# ## Create a training script that support Horovod distributed training
#
#
# ----
# ### TODO 1. Start horovod
# Horovod에 대응하기 위해 `main()` 함수에 아래 코드를 추가합니다.
#
# ```python
#     import horovod.keras as hvd
#     hvd.init()
#     config = tf.ConfigProto()
#     config.gpu_options.allow_growth = True
#     config.gpu_options.visible_device_list = str(hvd.local_rank())
#     K.set_session(tf.Session(config=config))
# ```
#
# ----
# ### TODO 2. Configure callbacks
# `main()` 함수에서 callbacks을 추가합니다.
#
# ```python
#     callbacks.append(hvd.callbacks.BroadcastGlobalVariablesCallback(0))
#     callbacks.append(hvd.callbacks.MetricAverageCallback())
#     callbacks.append(hvd.callbacks.LearningRateWarmupCallback(warmup_epochs=5, verbose=1))
# ```
#
# `hvd.rank () == 0` 에서만 실행되도록 체크포인트 및 TensorBoard 콜백을 변경해 주세요.
# ```python
#     if hvd.rank() == 0:
#         callbacks.append(ModelCheckpoint(args.output_dir + '/checkpoint-{epoch}.h5'))
# ```
#
# ----
# ### TODO 3. Configure the optimizer
# Horovod에 대응하기 위해 아래의 절차들을 진행합니다.
#
#
# 1) `keras_model_fn` 함수에 hvd 인수를 추가합니다.
# ```python
# # Add hvd to the function. also add it in the function call
# def keras_model_fn(learning_rate, weight_decay, optimizer, momentum, hvd):
# ```
#
# 2) `size=1`을 `size=hvd.size()`로 변경해 주세요.
#
# 3) 코드를 아래와 같이 수정합니다.
#
# ```python
#  model.compile(loss='categorical_crossentropy',
#                   optimizer=opt,
#                   metrics=['accuracy'])
# ```
# 바로 앞에
# ```python
# opt = hvd.DistributedOptimizer(opt)
# ```
# 라인을 추가해 주세요.
#
# 4) `main()` 함수에서 model 인스턴스를 만들 때 hvd를 인수로 전달하도록 수정합니다.
#
# ```python
# model = keras_model_fn(args.learning_rate, args.weight_decay, args.optimizer, args.momentum, hvd)
# ```

# %% [markdown]
# ## Run Distributed training
# 아래의 설정을 Estimator 객체에 전달하여 Horovod 분산 학습에 대한 설정을 할 수 있습니다.
# ```python
# distributions = {'mpi': {
#                     'enabled': True,
#                     'processes_per_host': # Number of Horovod processes per host
#                         }
#                 }
# ```

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()

# %%
dataset_location = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-cifar10-tf')
display(dataset_location)
# Out:
# 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf'

# %%
from sagemaker.tensorflow import TensorFlow

train_instance_type='ml.p3.8xlarge'
train_instance_count = 1
gpus_per_host = 4

num_of_shards = gpus_per_host * train_instance_count

# %%
distributions = {'mpi': {
                    'enabled': True,
                    'processes_per_host': gpus_per_host
                        }
                }

metric_definitions = [
    {'Name': 'train:loss', 'Regex': '.*loss: ([0-9\\.]+) - accuracy: [0-9\\.]+.*'},
    {'Name': 'train:accuracy', 'Regex': '.*loss: [0-9\\.]+ - accuracy: ([0-9\\.]+).*'},
    {'Name': 'validation:accuracy', 'Regex': '.* - loss: [0-9\\.]+ - accuracy: [0-9\\.]+ - val_loss: [0-9\\.]+ - val_accuracy: ([0-9\\.]+).*'},
    {'Name': 'validation:loss', 'Regex': '.* - loss: [0-9\\.]+ - accuracy: [0-9\\.]+ - val_loss: ([0-9\\.]+) - val_accuracy: [0-9\\.]+.*'},
    {'Name': 'sec/steps', 'Regex': '.* ([0-9]+)ms/step - loss: [0-9\\.]+ - accuracy: [0-9\\.]+ - val_loss: [0-9\\.]+ - val_accuracy: [0-9\\.]+'}
]
hyperparameters = {'epochs': 20, 'batch-size' : 256}

input_mode = 'File'

# %%
source_dir = os.path.join(os.getcwd(), 'training_script')
estimator_dist = TensorFlow(base_job_name='horovod-cifar10-tf',
                       entry_point='cifar10_keras_dist_tf2.py',
                       source_dir=source_dir,
                       role=role,
                       framework_version='2.1.0',
                       py_version='py3',
                       hyperparameters=hyperparameters,
                       train_instance_count=train_instance_count,
                       train_instance_type=train_instance_type,
                       tags = [{'Key' : 'Project', 'Value' : 'cifar10'},{'Key' : 'TensorBoard', 'Value' : 'horovod'}],
                       metric_definitions=metric_definitions,
                       distributions=distributions,
                       input_mode=input_mode)
# Out:
# Parameter distribution will be renamed to {'mpi': {'enabled': True, 'processes_per_host': 4}} in SageMaker Python SDK v2.

# %% [markdown]
# ### Data split for Horovod and upload to S3

# %% [markdown]
# For Horovod, we need a dedicated input channel for each Horovod worker. In this example, we will use a instance with 4 GPUs (**ml.p3.8xlarge**). So we will shard the train data into four tfrecord files as below.

# %%
# %load_ext autoreload
#%reload_ext autoreload
# %autoreload 2

from shard import do_shard
from sagemaker.session import s3_input

def shard_data_and_upload(local_data_dir, num_of_shards):
    do_shard(local_data_dir, num_of_shards)
    dataset_location = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-cifar10-tf')
    display(dataset_location)

    shuffle_config = sagemaker.session.ShuffleConfig(234)
    print("shuffle_config:",shuffle_config)
    train_s3_uri_prefix = dataset_location

    remote_inputs = {}

    for idx in range(num_of_shards):
        train_s3_uri = f'{train_s3_uri_prefix}/train/{idx}/'
        train_s3_input = s3_input(train_s3_uri, shuffle_config=shuffle_config)
        remote_inputs[f'train_{idx}'] = train_s3_input
        
        remote_inputs['validation_{}'.format(idx)] = '{}/validation'.format(dataset_location)

    remote_inputs['validation'] = '{}/validation'.format(dataset_location)
    remote_inputs['eval'] = '{}/eval'.format(dataset_location)
    
    return remote_inputs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
remote_inputs = shard_data_and_upload('./data', num_of_shards)
remote_inputs
# Out:
# Generating ./data/train/0/train_0.tfrecords
# Generating ./data/train/1/train_1.tfrecords
# Generating ./data/train/2/train_2.tfrecords
# Generating ./data/train/3/train_3.tfrecords
# 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf'
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# shuffle_config: <sagemaker.session.ShuffleConfig object at 0x7f8531a5eda0>
# {'train_0': <sagemaker.inputs.s3_input at 0x7f8531a5e8d0>,
#  'validation_0': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_1': <sagemaker.inputs.s3_input at 0x7f8531a3c908>,
#  'validation_1': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_2': <sagemaker.inputs.s3_input at 0x7f8531a3c6d8>,
#  'validation_2': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_3': <sagemaker.inputs.s3_input at 0x7f8531a3cac8>,
#  'validation_3': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'validation': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'eval': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/eval'}

# %% [markdown]
# In this example, we set wait=False if you want to see the output logs, change this to wait=True

# %%
estimator_dist.fit(remote_inputs, wait=True)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-09-10 12:51:52 Starting - Starting the training job...
# 2020-09-10 12:51:54 Starting - Launching requested ML instances......
# 2020-09-10 12:52:59 Starting - Preparing the instances for training......
# 2020-09-10 12:54:18 Downloading - Downloading input data...
# 2020-09-10 12:54:36 Training - Downloading the training image......
# 2020-09-10 12:55:45 Training - Training image download completed. Training in progress..2020-09-10 12:55:50,103 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-09-10 12:55:50,509 sagemaker-containers INFO     Starting MPI run as worker node.
# 2020-09-10 12:55:50,509 sagemaker-containers INFO     Creating SSH daemon.
# 2020-09-10 12:55:50,517 sagemaker-containers INFO     Waiting for MPI workers to establish their SSH connections
# 2020-09-10 12:55:50,517 sagemaker-containers INFO     Env Hosts: ['algo-1'] Hosts: ['algo-1:4'] process_per_hosts: 4 num_processes: 4
# 2020-09-10 12:55:50,518 sagemaker-containers INFO     Network interface name: eth0
# 2020-09-10 12:55:50,564 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_num_of_processes_per_host": 4,
#         "sagemaker_mpi_custom_mpi_options": "",
#         "sagemaker_mpi_enabled": true
#     },
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "train_2": "/opt/ml/input/data/train_2",
#         "train_1": "/opt/ml/input/data/train_1",
#         "validation_3": "/opt/ml/input/data/validation_3",
#         "train_0": "/opt/ml/input/data/train_0",
#         "validation_2": "/opt/ml/input/data/validation_2",
#         "validation_1": "/opt/ml/input/data/validation_1",
#         "validation_0": "/opt/ml/input/data/validation_0",
#         "validation": "/opt/ml/input/data/validation",
#         "train_3": "/opt/ml/input/data/train_3"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 256,
#         "model_dir": "/opt/ml/model",
#         "epochs": 20
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_2": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_1": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_3": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_0": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_2": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_1": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_0": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_3": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "horovod-cifar10-tf-2020-09-10-12-51-52-315",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-51-52-315/source/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_dist_tf2",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_dist_tf2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":256,"epochs":20,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=cifar10_keras_dist_tf2.py
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":4}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train_0","train_1","train_2","train_3","validation","validation_0","validation_1","validation_2","validation_3"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_dist_tf2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-51-52-315/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":4},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train_0":"/opt/ml/input/data/train_0","train_1":"/opt/ml/input/data/train_1","train_2":"/opt/ml/input/data/train_2","train_3":"/opt/ml/input/data/train_3","validation":"/opt/ml/input/data/validation","validation_0":"/opt/ml/input/data/validation_0","validation_1":"/opt/ml/input/data/validation_1","validation_2":"/opt/ml/input/data/validation_2","validation_3":"/opt/ml/input/data/validation_3"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":256,"epochs":20,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"horovod-cifar10-tf-2020-09-10-12-51-52-315","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-51-52-315/source/sourcedir.tar.gz","module_name":"cifar10_keras_dist_tf2","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_dist_tf2.py"}
# SM_USER_ARGS=["--batch-size","256","--epochs","20","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAIN_2=/opt/ml/input/data/train_2
# SM_CHANNEL_TRAIN_1=/opt/ml/input/data/train_1
# SM_CHANNEL_VALIDATION_3=/opt/ml/input/data/validation_3
# SM_CHANNEL_TRAIN_0=/opt/ml/input/data/train_0
# SM_CHANNEL_VALIDATION_2=/opt/ml/input/data/validation_2
# SM_CHANNEL_VALIDATION_1=/opt/ml/input/data/validation_1
# SM_CHANNEL_VALIDATION_0=/opt/ml/input/data/validation_0
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN_3=/opt/ml/input/data/train_3
# SM_HP_BATCH-SIZE=256
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=20
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1:4 -np 4 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to socket -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.6/dist-packages/gethostname.cpython-36m-x86_64-linux-gnu.so -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_EVAL -x SM_CHANNEL_TRAIN_2 -x SM_CHANNEL_TRAIN_1 -x SM_CHANNEL_VALIDATION_3 -x SM_CHANNEL_TRAIN_0 -x SM_CHANNEL_VALIDATION_2 -x SM_CHANNEL_VALIDATION_1 -x SM_CHANNEL_VALIDATION_0 -x SM_CHANNEL_VALIDATION -x SM_CHANNEL_TRAIN_3 -x SM_HP_BATCH-SIZE -x SM_HP_MODEL_DIR -x SM_HP_EPOCHS -x PYTHONPATH /usr/bin/python3 -m mpi4py cifar10_keras_dist_tf2.py --batch-size 256 --epochs 20 --model_dir /opt/ml/model
#
#
#  Data for JOB [11405,1] offset 0 Total slots allocated 4
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-0-173-152#011Num slots: 4#011Max slots: 0#011Num procs: 4
#  #011Process OMPI jobid: [11405,1] App: 0 Process rank: 0 Bound: UNBOUND
#  #011Process OMPI jobid: [11405,1] App: 0 Process rank: 1 Bound: UNBOUND
#  #011Process OMPI jobid: [11405,1] App: 0 Process rank: 2 Bound: UNBOUND
#  #011Process OMPI jobid: [11405,1] App: 0 Process rank: 3 Bound: UNBOUND
#
#  =============================================================
# --------------------------------------------------------------------------
# WARNING: Open MPI tried to bind a process but failed.  This is a
# warning only; your job will continue, though performance may
# be degraded.
#
#   Local host:        ip-10-0-173-152
#   Application name:  /usr/bin/python3
#   Error message:     failed to bind memory
#   Location:          rtc_hwloc.c:447
#
# --------------------------------------------------------------------------
# [1,1]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-51-52-315/model
# [1,1]<stderr>:Using TensorFlow backend.
# [1,2]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-51-52-315/model
# [1,2]<stderr>:Using TensorFlow backend.
# [1,3]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-51-52-315/model
# [1,3]<stderr>:Using TensorFlow backend.
# [1,0]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-51-52-315/model
# [1,0]<stderr>:Using TensorFlow backend.
# [ip-10-0-173-152.us-east-2.compute.internal:00053] 3 more processes have sent help message help-orte-odls-default.txt / memory not bound
# [ip-10-0-173-152.us-east-2.compute.internal:00053] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [1,1]<stderr>:INFO:root:Starting training
# [1,2]<stderr>:INFO:root:Starting training
# [1,0]<stderr>:INFO:root:Starting training
# [1,3]<stderr>:INFO:root:Starting training
# [1,0]<stdout>:[2020-09-10 12:55:56.612 algo-1:58 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,1]<stdout>:[2020-09-10 12:55:56.612 algo-1:59 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,2]<stdout>:[2020-09-10 12:55:56.612 algo-1:60 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,0]<stdout>:[2020-09-10 12:55:56.612 algo-1:58 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,1]<stdout>:[2020-09-10 12:55:56.612 algo-1:59 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,2]<stdout>:[2020-09-10 12:55:56.613 algo-1:60 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,1]<stdout>:[2020-09-10 12:55:56.613 algo-1:59 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,0]<stdout>:[2020-09-10 12:55:56.613 algo-1:58 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,2]<stdout>:[2020-09-10 12:55:56.613 algo-1:60 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,3]<stdout>:[2020-09-10 12:55:56.633 algo-1:61 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,3]<stdout>:[2020-09-10 12:55:56.634 algo-1:61 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,3]<stdout>:[2020-09-10 12:55:56.634 algo-1:61 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,1]<stdout>:[2020-09-10 12:55:56.655 algo-1:59 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,2]<stdout>:[2020-09-10 12:55:56.655 algo-1:60 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,2]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,3]<stdout>:[2020-09-10 12:55:56.664 algo-1:61 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:[2020-09-10 12:55:57.101 algo-1:58 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:[2020-09-10 12:56:00.289 algo-1:59 INFO hook.py:364] Monitoring the collections: metrics, losses, sm_metrics
# [1,3]<stdout>:[2020-09-10 12:56:00.306 algo-1:61 INFO hook.py:364] Monitoring the collections: metrics, losses, sm_metrics
# [1,2]<stdout>:[2020-09-10 12:56:00.371 algo-1:60 INFO hook.py:364] Monitoring the collections: losses, sm_metrics, metrics
# [1,0]<stdout>:[2020-09-10 12:56:00.749 algo-1:58 INFO hook.py:364] Monitoring the collections: losses, sm_metrics, metrics
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.173.152<0>
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,0]<stdout>:
# [1,0]<stdout>:algo-1:58:213 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:NCCL version 2.4.7+cuda10.1
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO NET/Socket : Using [0]eth0:10.0.173.152<0>
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO NET/Socket : Using [0]eth0:10.0.173.152<0>
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO NET/Socket : Using [0]eth0:10.0.173.152<0>
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,2]<stdout>:
# [1,2]<stdout>:algo-1:60:211 [2] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,3]<stdout>:
# [1,3]<stdout>:algo-1:61:212 [3] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,1]<stdout>:
# [1,1]<stdout>:algo-1:59:210 [1] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Setting affinity for GPU 3 to ffffffff
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Setting affinity for GPU 2 to ffffffff
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Setting affinity for GPU 1 to ffffffff
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Setting affinity for GPU 0 to ffffffff
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Channel 00 :    0   1   2   3
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Channel 01 :    0   2   1   3
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Channel 02 :    0   3   1   2
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Channel 03 :    0   3   2   1
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Channel 04 :    0   1   2   3
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Channel 05 :    0   2   1   3
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Channel 06 :    0   3   1   2
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Channel 07 :    0   3   2   1
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 00 : 1[1] -> 2[2] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Ring 00 : 0[0] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Ring 00 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 00 : 2[2] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 01 : 1[1] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Ring 01 : 0[0] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Ring 01 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 01 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Ring 02 : 0[0] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 02 : 1[1] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Ring 02 : 3[3] -> 1[1] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 02 : 2[2] -> 0[0] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 03 : 1[1] -> 0[0] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Ring 03 : 0[0] -> 3[3] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 03 : 2[2] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Ring 03 : 3[3] -> 2[2] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 04 : 1[1] -> 2[2] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Ring 04 : 0[0] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Ring 04 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 04 : 2[2] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 05 : 1[1] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Ring 05 : 0[0] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Ring 05 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 05 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Ring 06 : 0[0] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 06 : 1[1] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Ring 06 : 3[3] -> 1[1] via P2P/IPC
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 06 : 2[2] -> 0[0] via P2P/IPC
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO Ring 07 : 1[1] -> 0[0] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Ring 07 : 0[0] -> 3[3] via P2P/IPC
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO Ring 07 : 3[3] -> 2[2] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Using 256 threads, Min Comp Cap 7, Trees disabled
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO Ring 07 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO comm 0x7faab030f460 rank 0 nranks 4 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,1]<stdout>:algo-1:59:210 [1] NCCL INFO comm 0x7fb3d830edb0 rank 1 nranks 4 cudaDev 1 nvmlDev 1 - Init COMPLETE
# [1,3]<stdout>:algo-1:61:212 [3] NCCL INFO comm 0x7f5b1030e930 rank 3 nranks 4 cudaDev 3 nvmlDev 3 - Init COMPLETE
# [1,2]<stdout>:algo-1:60:211 [2] NCCL INFO comm 0x7fd30830edb0 rank 2 nranks 4 cudaDev 2 nvmlDev 2 - Init COMPLETE
# [1,0]<stdout>:algo-1:58:213 [0] NCCL INFO Launch mode Parallel
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 73728, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 294912, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 294912, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 294912, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 18432, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 18432, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 18432, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 36864, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 36864, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 36864, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 10240, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 10240, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 10240, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 524288, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 524288, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 524288, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 147456, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 147456, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 147456, errno = 1
# [1,0]<stderr>:[algo-1:00058] Read -1, expected 5785, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 18432, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 18432, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 18432, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 73728, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 73728, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 73728, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 73728, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# ...
# [1,0]<stdout>:Epoch 2/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00002: saving model to /opt/ml/output/checkpoint-2.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 1.6832 - accuracy: 0.3633 - val_loss: 1.9909 - val_accuracy: 0.2527
# [1,3]<stdout>:39/39 - 2s - loss: 1.6970 - accuracy: 0.3633 - val_loss: 1.9909 - val_accuracy: 0.2527
# [1,2]<stdout>:39/39 - 2s - loss: 1.6762 - accuracy: 0.3633 - val_loss: 1.9909 - val_accuracy: 0.2527
# [1,3]<stdout>:Epoch 3/20
# [1,1]<stdout>:Epoch 3/20
# [1,2]<stdout>:Epoch 3/20
# [1,0]<stdout>:39/39 - 2s - loss: 1.6845 - accuracy: 0.3633 - val_loss: 1.9909 - val_accuracy: 0.2527
# [1,0]<stdout>:Epoch 3/20
# [1,1]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00003: saving model to /opt/ml/output/checkpoint-3.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 1.5078 - accuracy: 0.4435 - val_loss: 2.0373 - val_accuracy: 0.3012
# [1,2]<stdout>:39/39 - 2s - loss: 1.4775 - accuracy: 0.4435 - val_loss: 2.0373 - val_accuracy: 0.3012
# [1,3]<stdout>:39/39 - 2s - loss: 1.5071 - accuracy: 0.4435 - val_loss: 2.0373 - val_accuracy: 0.3012
# [1,1]<stdout>:Epoch 4/20
# [1,2]<stdout>:Epoch 4/20
# [1,3]<stdout>:Epoch 4/20
# [1,0]<stdout>:39/39 - 2s - loss: 1.5027 - accuracy: 0.4435 - val_loss: 2.0373 - val_accuracy: 0.3012
# [1,0]<stdout>:Epoch 4/20
# [1,2]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00004: saving model to /opt/ml/output/checkpoint-4.ckpt
# [1,2]<stdout>:39/39 - 2s - loss: 1.3241 - accuracy: 0.5141 - val_loss: 1.6817 - val_accuracy: 0.3786
# [1,1]<stdout>:39/39 - 2s - loss: 1.3461 - accuracy: 0.5141 - val_loss: 1.6817 - val_accuracy: 0.3786
# [1,3]<stdout>:39/39 - 2s - loss: 1.3490 - accuracy: 0.5141 - val_loss: 1.6817 - val_accuracy: 0.3786
# [1,2]<stdout>:Epoch 5/20
# [1,1]<stdout>:Epoch 5/20
# [1,3]<stdout>:Epoch 5/20
# [1,0]<stdout>:39/39 - 2s - loss: 1.3325 - accuracy: 0.5141 - val_loss: 1.6817 - val_accuracy: 0.3786
# [1,0]<stdout>:Epoch 5/20
# [1,2]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,3]<stdout>:
# [1,3]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.004.
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.004.
# [1,2]<stdout>:
# [1,2]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.004.
# [1,1]<stdout>:
# [1,1]<stdout>:Epoch 5: finished gradual learning rate warmup to 0.004.
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00005: saving model to /opt/ml/output/checkpoint-5.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 1.2459 - accuracy: 0.5594 - val_loss: 1.4836 - val_accuracy: 0.4756
# [1,2]<stdout>:39/39 - 2s - loss: 1.2055 - accuracy: 0.5594 - val_loss: 1.4836 - val_accuracy: 0.4756
# [1,1]<stdout>:39/39 - 2s - loss: 1.2296 - accuracy: 0.5594 - val_loss: 1.4836 - val_accuracy: 0.4756
# [1,3]<stdout>:Epoch 6/20
# [1,2]<stdout>:Epoch 6/20
# [1,1]<stdout>:Epoch 6/20
# [1,0]<stdout>:39/39 - 2s - loss: 1.2278 - accuracy: 0.5594 - val_loss: 1.4836 - val_accuracy: 0.4756
# [1,0]<stdout>:Epoch 6/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00006: saving model to /opt/ml/output/checkpoint-6.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 1.1688 - accuracy: 0.5893 - val_loss: 1.7099 - val_accuracy: 0.4384
# [1,2]<stdout>:39/39 - 2s - loss: 1.1420 - accuracy: 0.5893 - val_loss: 1.7099 - val_accuracy: 0.4384
# [1,1]<stdout>:39/39 - 2s - loss: 1.1407 - accuracy: 0.5893 - val_loss: 1.7099 - val_accuracy: 0.4384
# [1,3]<stdout>:Epoch 7/20
# [1,2]<stdout>:Epoch 7/20
# [1,1]<stdout>:Epoch 7/20
# [1,0]<stdout>:39/39 - 2s - loss: 1.1466 - accuracy: 0.5893 - val_loss: 1.7099 - val_accuracy: 0.4384
# [1,0]<stdout>:Epoch 7/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00007: saving model to /opt/ml/output/checkpoint-7.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 1.0577 - accuracy: 0.6254 - val_loss: 1.3088 - val_accuracy: 0.5407
# [1,2]<stdout>:39/39 - 2s - loss: 1.0244 - accuracy: 0.6254 - val_loss: 1.3088 - val_accuracy: 0.5407
# [1,1]<stdout>:39/39 - 2s - loss: 1.0764 - accuracy: 0.6254 - val_loss: 1.3088 - val_accuracy: 0.5407
# [1,3]<stdout>:Epoch 8/20
# [1,2]<stdout>:Epoch 8/20
# [1,1]<stdout>:Epoch 8/20
# [1,0]<stdout>:39/39 - 2s - loss: 1.0430 - accuracy: 0.6254 - val_loss: 1.3088 - val_accuracy: 0.5407
# [1,0]<stdout>:Epoch 8/20
# [1,3]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00008: saving model to /opt/ml/output/checkpoint-8.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 0.9989 - accuracy: 0.6517 - val_loss: 1.1725 - val_accuracy: 0.6081
# [1,2]<stdout>:39/39 - 2s - loss: 0.9776 - accuracy: 0.6517 - val_loss: 1.1725 - val_accuracy: 0.6081
# [1,1]<stdout>:39/39 - 2s - loss: 0.9996 - accuracy: 0.6517 - val_loss: 1.1725 - val_accuracy: 0.6081
# [1,2]<stdout>:Epoch 9/20
# [1,1]<stdout>:Epoch 9/20
# [1,3]<stdout>:Epoch 9/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.9827 - accuracy: 0.6517 - val_loss: 1.1725 - val_accuracy: 0.6081
# [1,0]<stdout>:Epoch 9/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00009: saving model to /opt/ml/output/checkpoint-9.ckpt
# [1,2]<stdout>:39/39 - 2s - loss: 0.9409 - accuracy: 0.6671 - val_loss: 1.0244 - val_accuracy: 0.6410
# [1,1]<stdout>:39/39 - 2s - loss: 0.9457 - accuracy: 0.6671 - val_loss: 1.0244 - val_accuracy: 0.6410
# [1,3]<stdout>:39/39 - 2s - loss: 0.9612 - accuracy: 0.6671 - val_loss: 1.0244 - val_accuracy: 0.6410
# [1,2]<stdout>:Epoch 10/20
# [1,1]<stdout>:Epoch 10/20
# [1,3]<stdout>:Epoch 10/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.9283 - accuracy: 0.6671 - val_loss: 1.0244 - val_accuracy: 0.6410
# [1,0]<stdout>:Epoch 10/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00010: saving model to /opt/ml/output/checkpoint-10.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 0.8924 - accuracy: 0.6901 - val_loss: 0.9118 - val_accuracy: 0.6786
# [1,3]<stdout>:39/39 - 2s - loss: 0.8963 - accuracy: 0.6901 - val_loss: 0.9118 - val_accuracy: 0.6786
# [1,2]<stdout>:39/39 - 2s - loss: 0.8752 - accuracy: 0.6901 - val_loss: 0.9118 - val_accuracy: 0.6786
# [1,1]<stdout>:Epoch 11/20
# [1,3]<stdout>:Epoch 11/20
# [1,2]<stdout>:Epoch 11/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.8940 - accuracy: 0.6901 - val_loss: 0.9118 - val_accuracy: 0.6786
# [1,0]<stdout>:Epoch 11/20
# [1,0]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00011: saving model to /opt/ml/output/checkpoint-11.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 0.8570 - accuracy: 0.7001 - val_loss: 0.8643 - val_accuracy: 0.6929
# [1,2]<stdout>:39/39 - 2s - loss: 0.8347 - accuracy: 0.7001 - val_loss: 0.8643 - val_accuracy: 0.6929
# [1,3]<stdout>:39/39 - 2s - loss: 0.8768 - accuracy: 0.7001 - val_loss: 0.8643 - val_accuracy: 0.6929
# [1,1]<stdout>:Epoch 12/20
# [1,2]<stdout>:Epoch 12/20
# [1,3]<stdout>:Epoch 12/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.8722 - accuracy: 0.7001 - val_loss: 0.8643 - val_accuracy: 0.6929
# [1,0]<stdout>:Epoch 12/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00012: saving model to /opt/ml/output/checkpoint-12.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 0.8238 - accuracy: 0.7155 - val_loss: 0.8420 - val_accuracy: 0.7101
# [1,3]<stdout>:39/39 - 2s - loss: 0.8358 - accuracy: 0.7155 - val_loss: 0.8420 - val_accuracy: 0.7101
# [1,2]<stdout>:39/39 - 2s - loss: 0.8025 - accuracy: 0.7155 - val_loss: 0.8420 - val_accuracy: 0.7101
# [1,1]<stdout>:Epoch 13/20
# [1,2]<stdout>:Epoch 13/20
# [1,3]<stdout>:Epoch 13/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.8106 - accuracy: 0.7155 - val_loss: 0.8420 - val_accuracy: 0.7101
# [1,0]<stdout>:Epoch 13/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00013: saving model to /opt/ml/output/checkpoint-13.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 0.7941 - accuracy: 0.7256 - val_loss: 0.7529 - val_accuracy: 0.7343
# [1,1]<stdout>:39/39 - 2s - loss: 0.7862 - accuracy: 0.7256 - val_loss: 0.7529 - val_accuracy: 0.7343
# [1,2]<stdout>:39/39 - 2s - loss: 0.7891 - accuracy: 0.7256 - val_loss: 0.7529 - val_accuracy: 0.7343
# [1,3]<stdout>:Epoch 14/20
# [1,1]<stdout>:Epoch 14/20
# [1,2]<stdout>:Epoch 14/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7995 - accuracy: 0.7256 - val_loss: 0.7529 - val_accuracy: 0.7343
# [1,0]<stdout>:Epoch 14/20
# [1,1]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00014: saving model to /opt/ml/output/checkpoint-14.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 0.7760 - accuracy: 0.7406 - val_loss: 0.7958 - val_accuracy: 0.7237
# [1,1]<stdout>:39/39 - 2s - loss: 0.7635 - accuracy: 0.7406 - val_loss: 0.7958 - val_accuracy: 0.7237
# [1,2]<stdout>:39/39 - 2s - loss: 0.7456 - accuracy: 0.7406 - val_loss: 0.7958 - val_accuracy: 0.7237
# [1,3]<stdout>:Epoch 15/20
# [1,1]<stdout>:Epoch 15/20
# [1,2]<stdout>:Epoch 15/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7646 - accuracy: 0.7406 - val_loss: 0.7958 - val_accuracy: 0.7237
# [1,0]<stdout>:Epoch 15/20
# [1,0]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00015: saving model to /opt/ml/output/checkpoint-15.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 0.7529 - accuracy: 0.7443 - val_loss: 0.6820 - val_accuracy: 0.7576
# [1,2]<stdout>:39/39 - 2s - loss: 0.7306 - accuracy: 0.7443 - val_loss: 0.6820 - val_accuracy: 0.7576
# [1,1]<stdout>:39/39 - 2s - loss: 0.7414 - accuracy: 0.7443 - val_loss: 0.6820 - val_accuracy: 0.7576
# [1,3]<stdout>:Epoch 16/20
# [1,2]<stdout>:Epoch 16/20
# [1,1]<stdout>:Epoch 16/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7183 - accuracy: 0.7443 - val_loss: 0.6820 - val_accuracy: 0.7576
# [1,0]<stdout>:Epoch 16/20
# [1,2]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00016: saving model to /opt/ml/output/checkpoint-16.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 0.7113 - accuracy: 0.7494 - val_loss: 0.8321 - val_accuracy: 0.7199
# [1,3]<stdout>:39/39 - 2s - loss: 0.7597 - accuracy: 0.7494 - val_loss: 0.8321 - val_accuracy: 0.7199
# [1,2]<stdout>:39/39 - 2s - loss: 0.7083 - accuracy: 0.7494 - val_loss: 0.8321 - val_accuracy: 0.7199
# [1,1]<stdout>:Epoch 17/20
# [1,3]<stdout>:Epoch 17/20
# [1,2]<stdout>:Epoch 17/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7195 - accuracy: 0.7494 - val_loss: 0.8321 - val_accuracy: 0.7199
# [1,0]<stdout>:Epoch 17/20
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00017: saving model to /opt/ml/output/checkpoint-17.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 0.6912 - accuracy: 0.7621 - val_loss: 0.8690 - val_accuracy: 0.7094
# [1,3]<stdout>:39/39 - 2s - loss: 0.7071 - accuracy: 0.7621 - val_loss: 0.8690 - val_accuracy: 0.7094
# [1,2]<stdout>:39/39 - 2s - loss: 0.6857 - accuracy: 0.7621 - val_loss: 0.8690 - val_accuracy: 0.7094
# [1,1]<stdout>:Epoch 18/20
# [1,3]<stdout>:Epoch 18/20
# [1,2]<stdout>:Epoch 18/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7059 - accuracy: 0.7621 - val_loss: 0.8690 - val_accuracy: 0.7094
# [1,0]<stdout>:Epoch 18/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00018: saving model to /opt/ml/output/checkpoint-18.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 0.6766 - accuracy: 0.7673 - val_loss: 0.8855 - val_accuracy: 0.7048
# [1,1]<stdout>:39/39 - 2s - loss: 0.6807 - accuracy: 0.7673 - val_loss: 0.8855 - val_accuracy: 0.7048
# [1,2]<stdout>:39/39 - 2s - loss: 0.6595 - accuracy: 0.7673 - val_loss: 0.8855 - val_accuracy: 0.7048
# [1,3]<stdout>:Epoch 19/20
# [1,1]<stdout>:Epoch 19/20
# [1,2]<stdout>:Epoch 19/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.6644 - accuracy: 0.7673 - val_loss: 0.8855 - val_accuracy: 0.7048
# [1,0]<stdout>:Epoch 19/20
# [1,1]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00019: saving model to /opt/ml/output/checkpoint-19.ckpt
# [1,1]<stdout>:39/39 - 1s - loss: 0.6985 - accuracy: 0.7698 - val_loss: 0.6956 - val_accuracy: 0.7686
# [1,2]<stdout>:39/39 - 1s - loss: 0.6531 - accuracy: 0.7698 - val_loss: 0.6956 - val_accuracy: 0.7686
# [1,3]<stdout>:39/39 - 1s - loss: 0.6974 - accuracy: 0.7698 - val_loss: 0.6956 - val_accuracy: 0.7686
# [1,2]<stdout>:Epoch 20/20
# [1,3]<stdout>:Epoch 20/20
# [1,1]<stdout>:Epoch 20/20
# [1,0]<stdout>:39/39 - 1s - loss: 0.6583 - accuracy: 0.7698 - val_loss: 0.6956 - val_accuracy: 0.7686
# [1,0]<stdout>:Epoch 20/20
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00020: saving model to /opt/ml/output/checkpoint-20.ckpt
# [1,2]<stdout>:39/39 - 1s - loss: 0.6373 - accuracy: 0.7767 - val_loss: 0.6897 - val_accuracy: 0.7727
# [1,1]<stdout>:39/39 - 1s - loss: 0.6555 - accuracy: 0.7767 - val_loss: 0.6897 - val_accuracy: 0.7727
# [1,3]<stdout>:39/39 - 1s - loss: 0.6712 - accuracy: 0.7767 - val_loss: 0.6897 - val_accuracy: 0.7727
# [1,2]<stdout>:[2020-09-10 12:56:47.234 algo-1:60 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,3]<stdout>:[2020-09-10 12:56:47.235 algo-1:61 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,1]<stdout>:[2020-09-10 12:56:47.235 algo-1:59 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,0]<stdout>:39/39 - 1s - loss: 0.6459 - accuracy: 0.7767 - val_loss: 0.6897 - val_accuracy: 0.7727
# [1,0]<stdout>:39/39 - 1s - loss: 0.6884 - accuracy: 0.7693
# [1,0]<stderr>:INFO:root:Test loss:0.6883675929827567
# [1,0]<stderr>:INFO:root:Test accuracy:0.7693309187889099
# [1,0]<stderr>:2020-09-10 12:56:49.830980: W tensorflow/python/util/util.cc:319] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:If using Keras pass *_constraint arguments to layers.
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:If using Keras pass *_constraint arguments to layers.[1,0]<stderr>:
# [1,0]<stderr>:INFO:tensorflow:Assets written to: /opt/ml/model/assets
# [1,0]<stderr>:INFO:tensorflow:Assets written to: /opt/ml/model/assets
# [1,0]<stdout>:[2020-09-10 12:56:51.688 algo-1:58 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# 2020-09-10 12:56:52,743 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving containers. The SavedModel bundle is under directory "model", not a numeric name.
# 2020-09-10 12:56:52,744 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-09-10 12:57:04 Uploading - Uploading generated training model
# 2020-09-10 12:57:04 Completed - Training job completed
# Training seconds: 166
# Billable seconds: 166

# %% [markdown]
# ## Distributed training with Horovod and Pipe Mode input
# Ditributed training with Horovod can also utilize SageMaker Pipe Mode.

# %% [markdown]
# Amazon SageMaker를 사용하면 Pipe 입력 모드를 사용하여 교육 작업을 생성할 수 있습니다. **Pipe 입력 모드를 사용하면 S3의 학습 데이터셋을 노트북 인스턴스의 로컬 디스크로 다운로드하는 대신 학습 인스턴스로 직접 스트리밍합니다.** 즉, 학습 작업이 더 빨리 시작되고 더 빨리 완료되며 더 적은 디스크 공간이 필요합니다.
#
# SageMaker TensorFlow는 SageMaker에서 Pipe 입력 모드를 쉽게 활용할 수있는 `tf.data.Dataset`의 구현을 제공합니다. `tf.data.Dataset`을`sagemaker_tensorflow.PipeModeDataset`으로 바꾸면 학습 인스턴스로 스트리밍되는 TFRecord를 읽을 수 있습니다.
#
# 여러분의 entry_point 스크립트에서 `PipeModeDataset`을 `Dataset`처럼 사용할 수 있습니다. 아래 예시는 '학습' 채널에서 TFRecords를 읽을 수있는`PipeModeDataset`을 생성하는 예시입니다.
#
# ```python
# from sagemaker_tensorflow import PipeModeDataset
#
# features = {
#     'data': tf.FixedLenFeature([], tf.string),
#     'labels': tf.FixedLenFeature([], tf.int64),
# }
#
# def parse(record):
#     parsed = tf.parse_single_example(record, features)
#     return ({
#         'data': tf.decode_raw(parsed['data'], tf.float64)
#     }, parsed['labels'])
#
# def train_input_fn(training_dir, hyperparameters):
#     ds = PipeModeDataset(channel='training', record_format='TFRecord')
#     ds = ds.repeat(20)
#     ds = ds.prefetch(10)
#     ds = ds.map(parse, num_parallel_calls=10)
#     ds = ds.batch(64)
#     return ds
# ```
#
# Pipe 입력 모드에서 학습 작업을 구동하려면, 아래 예시처럼 여러분의 TensorFlow Estimator에서 `input_mode='Pipe'` 인자를 추가해 주세요.
#
# ```python
# from sagemaker.tensorflow import TensorFlow
#
# tf_estimator = TensorFlow(entry_point='tf-train-with-pipemodedataset.py', role='SageMakerRole',
#                           train_instance_count=1, train_instance_type='ml.c5.2xlarge',
#                           framework_version='1.14.0', input_mode='Pipe')
#
# tf_estimator.fit('s3://bucket/path/to/training/data')
# ```

# %% [markdown]
# ## Create a training script that support pipemode datasets
#
# ----
# ### TODO 1.
# `cifar10_keras_pipe_tf2.py`에서 아래와 같이 `PipeModeDataset`를 import해 주세요.
# ```python
# from sagemaker_tensorflow import PipeModeDataset
# ```
# ----
# ### TODO 2.
# ```python
# def _input(epochs, batch_size, channel, channel_name):
# ```
# 함수 내에서
# ```python
# dataset = tf.data.TFRecordDataset(filenames)
# ```
# 을
# ```python
# dataset = PipeModeDataset(channel=channel_name, record_format='TFRecord')
# ```
# 로 수정해 주세요.
#
# 자세한 내용은 SageMaker-python-sdk [documentation](https://sagemaker.readthedocs.io/en/stable/using_tf.html#training-with-pipe-mode-using-pipemodedataset)를 참조해 주세요.

# %%
from sagemaker.tensorflow import TensorFlow

train_instance_type='ml.p3.8xlarge'
train_instance_count = 1
gpus_per_host = 4

num_of_shards = gpus_per_host * train_instance_count

# %%
distributions = {'mpi': {
                    'enabled': True,
                    'processes_per_host': gpus_per_host
                        }
                }

metric_definitions = [
    {'Name': 'train:loss', 'Regex': '.*loss: ([0-9\\.]+) - acc: [0-9\\.]+.*'},
    {'Name': 'train:accuracy', 'Regex': '.*loss: [0-9\\.]+ - acc: ([0-9\\.]+).*'},
    {'Name': 'validation:accuracy', 'Regex': '.*step - loss: [0-9\\.]+ - acc: [0-9\\.]+ - val_loss: [0-9\\.]+ - val_acc: ([0-9\\.]+).*'},
    {'Name': 'validation:loss', 'Regex': '.*step - loss: [0-9\\.]+ - acc: [0-9\\.]+ - val_loss: ([0-9\\.]+) - val_acc: [0-9\\.]+.*'},
    {'Name': 'sec/steps', 'Regex': '.* - \d+s (\d+)[mu]s/step - loss: [0-9\\.]+ - acc: [0-9\\.]+ - val_loss: [0-9\\.]+ - val_acc: [0-9\\.]+'}
]

hyperparameters = {'epochs': 20, 'batch-size' : 256}

input_mode = 'Pipe'

# %%
remote_inputs = shard_data_and_upload('./data', num_of_shards)
# Out:
# Generating ./data/train/0/train_0.tfrecords
# Generating ./data/train/1/train_1.tfrecords
# Generating ./data/train/2/train_2.tfrecords
# Generating ./data/train/3/train_3.tfrecords
# 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf'
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# shuffle_config: <sagemaker.session.ShuffleConfig object at 0x7f853030b630>

# %%
remote_inputs
# Out:
# {'train_0': <sagemaker.inputs.s3_input at 0x7f853030b5f8>,
#  'validation_0': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_1': <sagemaker.inputs.s3_input at 0x7f853030bcf8>,
#  'validation_1': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_2': <sagemaker.inputs.s3_input at 0x7f853030b0b8>,
#  'validation_2': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'train_3': <sagemaker.inputs.s3_input at 0x7f85303e4c18>,
#  'validation_3': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'validation': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/validation',
#  'eval': 's3://sagemaker-us-east-2-870180618679/data/DEMO-cifar10-tf/eval'}

# %%
source_dir = os.path.join(os.getcwd(), 'training_script')
estimator_dist = TensorFlow(base_job_name='horovod-cifar10-tf',
                       entry_point='cifar10_keras_dist_tf2.py',
                       source_dir=source_dir,
                       role=role,
                       framework_version='2.1.0',
                       py_version='py3',
                       hyperparameters=hyperparameters,
                       train_instance_count=train_instance_count,
                       train_instance_type=train_instance_type,
                       tags = [{'Key' : 'Project', 'Value' : 'cifar10'},{'Key' : 'TensorBoard', 'Value' : 'horovod'}],
                       metric_definitions=metric_definitions,
                       distributions=distributions,
                       input_mode=input_mode)
# Out:
# Parameter distribution will be renamed to {'mpi': {'enabled': True, 'processes_per_host': 4}} in SageMaker Python SDK v2.

# %%
estimator_dist.fit(remote_inputs, wait=True)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-09-10 12:57:44 Starting - Starting the training job...
# 2020-09-10 12:57:45 Starting - Launching requested ML instances......
# 2020-09-10 12:59:07 Starting - Preparing the instances for training.........
# 2020-09-10 13:00:43 Downloading - Downloading input data
# 2020-09-10 13:00:43 Training - Downloading the training image.........
# 2020-09-10 13:02:03 Training - Training image download completed. Training in progress..2020-09-10 13:02:08,408 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-09-10 13:02:08,833 sagemaker-containers INFO     Starting MPI run as worker node.
# 2020-09-10 13:02:08,834 sagemaker-containers INFO     Creating SSH daemon.
# 2020-09-10 13:02:08,839 sagemaker-containers INFO     Waiting for MPI workers to establish their SSH connections
# 2020-09-10 13:02:08,839 sagemaker-containers INFO     Env Hosts: ['algo-1'] Hosts: ['algo-1:4'] process_per_hosts: 4 num_processes: 4
# 2020-09-10 13:02:08,841 sagemaker-containers INFO     Network interface name: eth0
# 2020-09-10 13:02:08,886 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_num_of_processes_per_host": 4,
#         "sagemaker_mpi_custom_mpi_options": "",
#         "sagemaker_mpi_enabled": true
#     },
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "train_2": "/opt/ml/input/data/train_2",
#         "train_1": "/opt/ml/input/data/train_1",
#         "validation_3": "/opt/ml/input/data/validation_3",
#         "train_0": "/opt/ml/input/data/train_0",
#         "validation_2": "/opt/ml/input/data/validation_2",
#         "validation_1": "/opt/ml/input/data/validation_1",
#         "validation_0": "/opt/ml/input/data/validation_0",
#         "validation": "/opt/ml/input/data/validation",
#         "train_3": "/opt/ml/input/data/train_3"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 256,
#         "model_dir": "/opt/ml/model",
#         "epochs": 20
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_2": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_1": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_3": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_0": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_2": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_1": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation_0": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train_3": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "horovod-cifar10-tf-2020-09-10-12-57-43-628",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-57-43-628/source/sourcedir.tar.gz",
#     "module_name": "cifar10_keras_dist_tf2",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10_keras_dist_tf2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":256,"epochs":20,"model_dir":"/opt/ml/model"}
# SM_USER_ENTRY_POINT=cifar10_keras_dist_tf2.py
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":4}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"train_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"train_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"train_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"train_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train_0","train_1","train_2","train_3","validation","validation_0","validation_1","validation_2","validation_3"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10_keras_dist_tf2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-57-43-628/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":4},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train_0":"/opt/ml/input/data/train_0","train_1":"/opt/ml/input/data/train_1","train_2":"/opt/ml/input/data/train_2","train_3":"/opt/ml/input/data/train_3","validation":"/opt/ml/input/data/validation","validation_0":"/opt/ml/input/data/validation_0","validation_1":"/opt/ml/input/data/validation_1","validation_2":"/opt/ml/input/data/validation_2","validation_3":"/opt/ml/input/data/validation_3"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":256,"epochs":20,"model_dir":"/opt/ml/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"train_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"train_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"train_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"train_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation_0":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation_1":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation_2":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"validation_3":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"horovod-cifar10-tf-2020-09-10-12-57-43-628","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-57-43-628/source/sourcedir.tar.gz","module_name":"cifar10_keras_dist_tf2","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10_keras_dist_tf2.py"}
# SM_USER_ARGS=["--batch-size","256","--epochs","20","--model_dir","/opt/ml/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAIN_2=/opt/ml/input/data/train_2
# SM_CHANNEL_TRAIN_1=/opt/ml/input/data/train_1
# SM_CHANNEL_VALIDATION_3=/opt/ml/input/data/validation_3
# SM_CHANNEL_TRAIN_0=/opt/ml/input/data/train_0
# SM_CHANNEL_VALIDATION_2=/opt/ml/input/data/validation_2
# SM_CHANNEL_VALIDATION_1=/opt/ml/input/data/validation_1
# SM_CHANNEL_VALIDATION_0=/opt/ml/input/data/validation_0
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN_3=/opt/ml/input/data/train_3
# SM_HP_BATCH-SIZE=256
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_EPOCHS=20
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1:4 -np 4 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to socket -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.6/dist-packages/gethostname.cpython-36m-x86_64-linux-gnu.so -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_EVAL -x SM_CHANNEL_TRAIN_2 -x SM_CHANNEL_TRAIN_1 -x SM_CHANNEL_VALIDATION_3 -x SM_CHANNEL_TRAIN_0 -x SM_CHANNEL_VALIDATION_2 -x SM_CHANNEL_VALIDATION_1 -x SM_CHANNEL_VALIDATION_0 -x SM_CHANNEL_VALIDATION -x SM_CHANNEL_TRAIN_3 -x SM_HP_BATCH-SIZE -x SM_HP_MODEL_DIR -x SM_HP_EPOCHS -x PYTHONPATH /usr/bin/python3 -m mpi4py cifar10_keras_dist_tf2.py --batch-size 256 --epochs 20 --model_dir /opt/ml/model
#
#
#  Data for JOB [37583,1] offset 0 Total slots allocated 4
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-0-76-70#011Num slots: 4#011Max slots: 0#011Num procs: 4
#  #011Process OMPI jobid: [37583,1] App: 0 Process rank: 0 Bound: UNBOUND
#  #011Process OMPI jobid: [37583,1] App: 0 Process rank: 1 Bound: UNBOUND
#  #011Process OMPI jobid: [37583,1] App: 0 Process rank: 2 Bound: UNBOUND
#  #011Process OMPI jobid: [37583,1] App: 0 Process rank: 3 Bound: UNBOUND
#
#  =============================================================
# --------------------------------------------------------------------------
# WARNING: Open MPI tried to bind a process but failed.  This is a
# warning only; your job will continue, though performance may
# be degraded.
#
#   Local host:        ip-10-0-76-70
#   Application name:  /usr/bin/python3
#   Error message:     failed to bind memory
#   Location:          rtc_hwloc.c:447
#
# --------------------------------------------------------------------------
# [1,3]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-57-43-628/model
# [1,0]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-57-43-628/model
# [1,3]<stderr>:Using TensorFlow backend.
# [1,0]<stderr>:Using TensorFlow backend.
# [1,1]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-57-43-628/model
# [1,1]<stderr>:Using TensorFlow backend.
# [1,2]<stderr>:INFO:root:Writing TensorBoard logs to s3://sagemaker-us-east-2-870180618679/horovod-cifar10-tf-2020-09-10-12-57-43-628/model
# [1,2]<stderr>:Using TensorFlow backend.
# [ip-10-0-76-70.us-east-2.compute.internal:00053] 3 more processes have sent help message help-orte-odls-default.txt / memory not bound
# [ip-10-0-76-70.us-east-2.compute.internal:00053] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [1,0]<stderr>:INFO:root:Starting training
# [1,2]<stderr>:INFO:root:Starting training
# [1,1]<stderr>:INFO:root:Starting training
# [1,3]<stderr>:INFO:root:Starting training
# [1,0]<stdout>:[2020-09-10 13:02:14.848 algo-1:58 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,2]<stdout>:[2020-09-10 13:02:14.848 algo-1:60 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,0]<stdout>:[2020-09-10 13:02:14.848 algo-1:58 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,2]<stdout>:[2020-09-10 13:02:14.848 algo-1:60 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,0]<stdout>:[2020-09-10 13:02:14.848 algo-1:58 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,2]<stdout>:[2020-09-10 13:02:14.848 algo-1:60 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,0]<stderr>:2020-09-10 13:02:14.850136: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stderr>:2020-09-10 13:02:14.850140: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stdout>:[2020-09-10 13:02:14.851 algo-1:59 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,1]<stdout>:[2020-09-10 13:02:14.852 algo-1:59 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,1]<stdout>:[2020-09-10 13:02:14.852 algo-1:59 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,1]<stderr>:2020-09-10 13:02:14.853563: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stdout>:[2020-09-10 13:02:14.891 algo-1:59 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,2]<stdout>:[2020-09-10 13:02:14.891 algo-1:60 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,3]<stdout>:[2020-09-10 13:02:14.916 algo-1:61 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,3]<stdout>:[2020-09-10 13:02:14.917 algo-1:61 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [1,3]<stdout>:[2020-09-10 13:02:14.917 algo-1:61 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [1,3]<stderr>:2020-09-10 13:02:14.919452: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,3]<stdout>:[2020-09-10 13:02:14.962 algo-1:61 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:[2020-09-10 13:02:15.309 algo-1:58 INFO keras.py:68] Executing in TF2.x eager mode.TF 2.x eager doesn't provide gradient and optimizer variable values.SageMaker Debugger will not be saving gradients and optimizer variables in this case
# [1,0]<stdout>:Epoch 1/20
# [1,2]<stdout>:[2020-09-10 13:02:18.853 algo-1:60 INFO hook.py:364] Monitoring the collections: losses, sm_metrics, metrics
# [1,1]<stdout>:[2020-09-10 13:02:18.963 algo-1:59 INFO hook.py:364] Monitoring the collections: metrics, sm_metrics, losses
# [1,3]<stdout>:[2020-09-10 13:02:18.987 algo-1:61 INFO hook.py:364] Monitoring the collections: losses, sm_metrics, metrics
# [1,0]<stdout>:[2020-09-10 13:02:19.326 algo-1:58 INFO hook.py:364] Monitoring the collections: losses, metrics, sm_metrics
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.76.70<0>
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,0]<stdout>:
# [1,0]<stdout>:algo-1:58:211 [0] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:NCCL version 2.4.7+cuda10.1
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO NET/Socket : Using [0]eth0:10.0.76.70<0>
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO NET/Socket : Using [0]eth0:10.0.76.70<0>
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO NET/Socket : Using [0]eth0:10.0.76.70<0>
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so).
# [1,3]<stdout>:
# [1,3]<stdout>:algo-1:61:210 [3] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,2]<stdout>:
# [1,2]<stdout>:algo-1:60:219 [2] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,1]<stdout>:
# [1,1]<stdout>:algo-1:59:212 [1] misc/ibvwrap.cc:63 NCCL WARN Failed to open libibverbs.so[.1]
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Setting affinity for GPU 0 to ffffffff
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Setting affinity for GPU 3 to ffffffff
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Setting affinity for GPU 1 to ffffffff
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Setting affinity for GPU 2 to ffffffff
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Channel 00 :    0   1   2   3
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Channel 01 :    0   2   1   3
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Channel 02 :    0   3   1   2
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Channel 03 :    0   3   2   1
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Channel 04 :    0   1   2   3
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Channel 05 :    0   2   1   3
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Channel 06 :    0   3   1   2
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Channel 07 :    0   3   2   1
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Ring 00 : 1[1] -> 2[2] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Ring 00 : 0[0] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Ring 00 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Ring 00 : 2[2] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Ring 01 : 1[1] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Ring 01 : 0[0] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Ring 01 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Ring 01 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Ring 02 : 0[0] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Ring 02 : 1[1] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Ring 02 : 3[3] -> 1[1] via P2P/IPC
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Ring 02 : 2[2] -> 0[0] via P2P/IPC
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Ring 03 : 1[1] -> 0[0] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Ring 03 : 0[0] -> 3[3] via P2P/IPC
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Ring 03 : 2[2] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Ring 03 : 3[3] -> 2[2] via P2P/IPC
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Ring 04 : 1[1] -> 2[2] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Ring 04 : 0[0] -> 1[1] via P2P/IPC
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Ring 04 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Ring 04 : 2[2] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Ring 05 : 1[1] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Ring 05 : 0[0] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Ring 05 : 3[3] -> 0[0] via P2P/IPC
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Ring 05 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Ring 06 : 0[0] -> 3[3] via P2P/IPC
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Ring 06 : 1[1] -> 2[2] via P2P/IPC
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Ring 06 : 3[3] -> 1[1] via P2P/IPC
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Ring 06 : 2[2] -> 0[0] via P2P/IPC
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO Ring 07 : 1[1] -> 0[0] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Ring 07 : 0[0] -> 3[3] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Using 256 threads, Min Comp Cap 7, Trees disabled
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO Ring 07 : 3[3] -> 2[2] via P2P/IPC
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO Ring 07 : 2[2] -> 1[1] via P2P/IPC
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO comm 0x7f58e431c1a0 rank 0 nranks 4 cudaDev 0 nvmlDev 0 - Init COMPLETE
# [1,1]<stdout>:algo-1:59:212 [1] NCCL INFO comm 0x7f73ec30d8d0 rank 1 nranks 4 cudaDev 1 nvmlDev 1 - Init COMPLETE
# [1,3]<stdout>:algo-1:61:210 [3] NCCL INFO comm 0x7fc8bc30d430 rank 3 nranks 4 cudaDev 3 nvmlDev 3 - Init COMPLETE
# [1,2]<stdout>:algo-1:60:219 [2] NCCL INFO comm 0x7f003830d8c0 rank 2 nranks 4 cudaDev 2 nvmlDev 2 - Init COMPLETE
# [1,0]<stdout>:algo-1:58:211 [0] NCCL INFO Launch mode Parallel
# [1,0]<stderr>:[algo-1:00058] Read -1, expected 4393, errno = 1
# [1,0]<stderr>:[algo-1:00058] Read -1, expected 4393, errno = 1
# [1,0]<stderr>:[algo-1:00058] Read -1, expected 4393, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 73728, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 73728, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 18432, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 18432, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 18432, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 10240, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 10240, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 10240, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 147456, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 147456, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 147456, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 524288, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 524288, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 524288, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 36864, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 36864, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 36864, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 294912, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 294912, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 294912, errno = 1
# [1,0]<stderr>:[algo-1:00058] Read -1, expected 4649, errno = 1
# [1,0]<stderr>:[algo-1:00058] Read -1, expected 5873, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 18432, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 18432, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 18432, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 147456, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 147456, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 147456, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 73728, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 73728, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 73728, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 73728, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,1]<stderr>:[algo-1:00059] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# [1,3]<stderr>:[algo-1:00061] Read -1, expected 8192, errno = 1
# [1,2]<stderr>:[algo-1:00060] Read -1, expected 8192, errno = 1
# ...
# [1,2]<stderr>:2020-09-10 13:02:54.270833: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,3]<stderr>:2020-09-10 13:02:54.271487: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2020-09-10 13:02:54.276798: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00013: saving model to /opt/ml/output/checkpoint-13.ckpt
# [1,2]<stdout>:39/39 - 2s - loss: 0.7669 - accuracy: 0.7273 - val_loss: 0.8080 - val_accuracy: 0.7180
# [1,1]<stdout>:39/39 - 2s - loss: 0.7792 - accuracy: 0.7273 - val_loss: 0.8080 - val_accuracy: 0.7180
# [1,3]<stdout>:39/39 - 2s - loss: 0.8105 - accuracy: 0.7273 - val_loss: 0.8080 - val_accuracy: 0.7180
# [1,2]<stdout>:Epoch 14/20
# [1,1]<stdout>:Epoch 14/20
# [1,3]<stdout>:Epoch 14/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7801 - accuracy: 0.7273 - val_loss: 0.8080 - val_accuracy: 0.7180
# [1,0]<stdout>:Epoch 14/20
# [1,2]<stderr>:2020-09-10 13:02:56.470492: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,3]<stderr>:2020-09-10 13:02:56.472137: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stderr>:2020-09-10 13:02:56.470491: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2020-09-10 13:02:56.483655: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00014: saving model to /opt/ml/output/checkpoint-14.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 0.7681 - accuracy: 0.7331 - val_loss: 0.7455 - val_accuracy: 0.7372
# [1,2]<stdout>:39/39 - 2s - loss: 0.7603 - accuracy: 0.7331 - val_loss: 0.7455 - val_accuracy: 0.7372
# [1,3]<stdout>:39/39 - 2s - loss: 0.8077 - accuracy: 0.7331 - val_loss: 0.7455 - val_accuracy: 0.7372
# [1,1]<stdout>:Epoch 15/20
# [1,2]<stdout>:Epoch 15/20
# [1,3]<stdout>:Epoch 15/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7617 - accuracy: 0.7331 - val_loss: 0.7455 - val_accuracy: 0.7372
# [1,0]<stdout>:Epoch 15/20
# [1,1]<stderr>:2020-09-10 13:02:58.642683: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stderr>:2020-09-10 13:02:58.643351: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,3]<stderr>:2020-09-10 13:02:58.644848: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2020-09-10 13:02:58.650800: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00015: saving model to /opt/ml/output/checkpoint-15.ckpt[1,0]<stdout>:
# [1,3]<stdout>:39/39 - 2s - loss: 0.7517 - accuracy: 0.7430 - val_loss: 0.7516 - val_accuracy: 0.7441
# [1,1]<stdout>:39/39 - 2s - loss: 0.7400 - accuracy: 0.7430 - val_loss: 0.7516 - val_accuracy: 0.7441
# [1,2]<stdout>:39/39 - 2s - loss: 0.7254 - accuracy: 0.7430 - val_loss: 0.7516 - val_accuracy: 0.7441
# [1,3]<stdout>:Epoch 16/20
# [1,1]<stdout>:Epoch 16/20
# [1,2]<stdout>:Epoch 16/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7387 - accuracy: 0.7430 - val_loss: 0.7516 - val_accuracy: 0.7441
# [1,0]<stdout>:Epoch 16/20
# [1,2]<stderr>:2020-09-10 13:03:00.843946: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,3]<stderr>:2020-09-10 13:03:00.843991: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stderr>:2020-09-10 13:03:00.844846: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2020-09-10 13:03:00.845972: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# 2020-09-10 13:03:15 Uploading - Uploading generated training model[1,0]<stdout>:
# [1,0]<stdout>:Epoch 00016: saving model to /opt/ml/output/checkpoint-16.ckpt
# [1,3]<stdout>:39/39 - 2s - loss: 0.7345 - accuracy: 0.7548 - val_loss: 0.8601 - val_accuracy: 0.7043
# [1,1]<stdout>:39/39 - 2s - loss: 0.7274 - accuracy: 0.7548 - val_loss: 0.8601 - val_accuracy: 0.7043
# [1,3]<stdout>:Epoch 17/20
# [1,1]<stdout>:Epoch 17/20
# [1,2]<stdout>:39/39 - 2s - loss: 0.6987 - accuracy: 0.7548 - val_loss: 0.8601 - val_accuracy: 0.7043
# [1,2]<stdout>:Epoch 17/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7057 - accuracy: 0.7548 - val_loss: 0.8601 - val_accuracy: 0.7043
# [1,0]<stdout>:Epoch 17/20
# [1,3]<stderr>:2020-09-10 13:03:03.008391: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stderr>:2020-09-10 13:03:03.009746: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stderr>:2020-09-10 13:03:03.011623: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2020-09-10 13:03:03.014944: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00017: saving model to /opt/ml/output/checkpoint-17.ckpt
# [1,2]<stdout>:39/39 - 2s - loss: 0.6829 - accuracy: 0.7595 - val_loss: 0.9324 - val_accuracy: 0.6927
# [1,1]<stdout>:39/39 - 2s - loss: 0.6979 - accuracy: 0.7595 - val_loss: 0.9324 - val_accuracy: 0.6927
# [1,3]<stdout>:39/39 - 2s - loss: 0.7105 - accuracy: 0.7595 - val_loss: 0.9324 - val_accuracy: 0.6927
# [1,2]<stdout>:Epoch 18/20
# [1,1]<stdout>:Epoch 18/20
# [1,3]<stdout>:Epoch 18/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.7057 - accuracy: 0.7595 - val_loss: 0.9324 - val_accuracy: 0.6927
# [1,0]<stdout>:Epoch 18/20
# [1,3]<stderr>:2020-09-10 13:03:05.186227: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stderr>:2020-09-10 13:03:05.186333: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stderr>:2020-09-10 13:03:05.186557: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2020-09-10 13:03:05.187149: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stdout>:Epoch 1/20
# [1,3]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00018: saving model to /opt/ml/output/checkpoint-18.ckpt
# [1,1]<stdout>:39/39 - 2s - loss: 0.6661 - accuracy: 0.7701 - val_loss: 0.7179 - val_accuracy: 0.7491
# [1,3]<stdout>:39/39 - 2s - loss: 0.6943 - accuracy: 0.7701 - val_loss: 0.7179 - val_accuracy: 0.7491
# [1,2]<stdout>:39/39 - 2s - loss: 0.6440 - accuracy: 0.7701 - val_loss: 0.7179 - val_accuracy: 0.7491
# [1,1]<stdout>:Epoch 19/20
# [1,3]<stdout>:Epoch 19/20
# [1,2]<stdout>:Epoch 19/20
# [1,0]<stdout>:39/39 - 2s - loss: 0.6679 - accuracy: 0.7701 - val_loss: 0.7179 - val_accuracy: 0.7491
# [1,0]<stdout>:Epoch 19/20
# [1,3]<stderr>:2020-09-10 13:03:06.605631: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stderr>:2020-09-10 13:03:06.605655: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stderr>:2020-09-10 13:03:06.605870: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2020-09-10 13:03:06.606406: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,3]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00019: saving model to /opt/ml/output/checkpoint-19.ckpt
# [1,2]<stdout>:39/39 - 1s - loss: 0.6507 - accuracy: 0.7738 - val_loss: 0.8568 - val_accuracy: 0.7076
# [1,1]<stdout>:39/39 - 1s - loss: 0.6575 - accuracy: 0.7738 - val_loss: 0.8568 - val_accuracy: 0.7076
# [1,3]<stdout>:39/39 - 1s - loss: 0.6665 - accuracy: 0.7738 - val_loss: 0.8568 - val_accuracy: 0.7076
# [1,2]<stdout>:Epoch 20/20
# [1,1]<stdout>:Epoch 20/20
# [1,3]<stdout>:Epoch 20/20
# [1,0]<stdout>:39/39 - 1s - loss: 0.6484 - accuracy: 0.7738 - val_loss: 0.8568 - val_accuracy: 0.7076
# [1,0]<stdout>:Epoch 20/20
# [1,3]<stderr>:2020-09-10 13:03:07.843741: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,1]<stderr>:2020-09-10 13:03:07.843979: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,2]<stderr>:2020-09-10 13:03:07.844009: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stderr>:2020-09-10 13:03:07.844561: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,3]<stdout>:Epoch 1/20
# [1,1]<stdout>:Epoch 1/20
# [1,2]<stdout>:Epoch 1/20
# [1,0]<stdout>:Epoch 1/20
# [1,0]<stdout>:
# [1,0]<stdout>:Epoch 00020: saving model to /opt/ml/output/checkpoint-20.ckpt
# [1,2]<stdout>:39/39 - 1s - loss: 0.6222 - accuracy: 0.7787 - val_loss: 0.6352 - val_accuracy: 0.7827
# [1,1]<stdout>:39/39 - 1s - loss: 0.6514 - accuracy: 0.7787 - val_loss: 0.6352 - val_accuracy: 0.7827
# [1,3]<stdout>:39/39 - 1s - loss: 0.6827 - accuracy: 0.7787 - val_loss: 0.6352 - val_accuracy: 0.7827
# [1,1]<stdout>:[2020-09-10 13:03:08.216 algo-1:59 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,2]<stdout>:[2020-09-10 13:03:08.216 algo-1:60 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,3]<stdout>:[2020-09-10 13:03:08.218 algo-1:61 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [1,0]<stdout>:39/39 - 1s - loss: 0.6251 - accuracy: 0.7787 - val_loss: 0.6352 - val_accuracy: 0.7827
# [1,0]<stderr>:2020-09-10 13:03:08.546422: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# [1,0]<stdout>:39/39 - 1s - loss: 0.6549 - accuracy: 0.7797
# [1,0]<stderr>:INFO:root:Test loss:0.65487323816006
# [1,0]<stderr>:INFO:root:Test accuracy:0.7797476053237915
# [1,0]<stderr>:2020-09-10 13:03:11.017940: W tensorflow/python/util/util.cc:319] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:If using Keras pass *_constraint arguments to layers.
# [1,0]<stderr>:WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# [1,0]<stderr>:Instructions for updating:
# [1,0]<stderr>:If using Keras pass *_constraint arguments to layers.
# [1,0]<stderr>:INFO:tensorflow:Assets written to: /opt/ml/model/assets
# [1,0]<stderr>:INFO:tensorflow:Assets written to: /opt/ml/model/assets
# [1,0]<stdout>:[2020-09-10 13:03:12.781 algo-1:58 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# 2020-09-10 13:03:13,817 sagemaker_tensorflow_container.training WARNING  Your model will NOT be servable with SageMaker TensorFlow Serving containers. The SavedModel bundle is under directory "model", not a numeric name.
# 2020-09-10 13:03:13,817 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-09-10 13:03:23 Completed - Training job completed
# Training seconds: 178
# Billable seconds: 178

# %% [markdown]
# 학습 완료 후 Billable seconds도 확인해 보세요. Billable seconds는 실제로 학습 수행 시 과금되는 시간입니다.
# ```
# Billable seconds: <time>
# ```
#
# 참고로, `ml.p2.xlarge` 인스턴스로 10 epoch 학습 시 전체 6분~7분이 소요되고, 실제 학습에 소요되는 시간은 3분~4분이 소요됩니다.

# %% [markdown]
# **수고 하셨습니다.**
#
# 여러 분은 이제 분산 학습에 SageMaker 학습 작업을 사용할 수 있습니다.
# 다음 노트북으로 계속 진행하기 전에 CloudWatch 및 TensorBoard의 distribution job metrics를 살펴 보세요.
# TensorBoard를 사용하여 여러분이 실행한 다른 작업을 비교할 수 있습니다.
#
# TensorBoard 실행 시 아래의 인자값을 참조해 주세요.<br>
# `--logdir dist:dist_model_dir,pipe:pipe_model_dir,file:normal_job_model_dir`
